# %% [markdown]
# # Chat con código local (parte 1, chunking y embedding)
#
# ![rag-codigo-local.jpg](../rag-codigo-local.jpg)
#
# ## 1. Examinar carpetas y archivos de código
#
# Para este ejemplo se tomarán en cuenta sólo archivos de terraform (`.tf .tfvars`) y relacionados como `.sh` o notas `.md`

# %%
# Algunos requerimientos
# !pip install chromadb
# !pip install langchain
# !pip install langchain_community
# !pip install langchain-text-splitters
# !pip install openai

# %%
import os

def get_first_summary_from_contents(content, 
                                    summary_strings=['# summary:', '# resumen:']):
    """Extracts summary text from comments of style:
    # Summary: Creates a simple Application Load Balancer and an ASG
    Returns: Creates a simple Application Load Balancer and an ASG
    """
    for line in content.split('\n'):
        lline = line.lower().strip()
        if any([lline.startswith(s) for s in summary_strings]):
            # to remove the matching comment string
            for s in summary_strings:
                if lline.startswith(s):
                    return line[len(s):].strip()
        return ''


def load_snippets(base_path, extensions=['.tf', '.tfvars', '.sh', '.md']):
    snippets = []
    for root, _, files in os.walk(base_path):
        for file in files:
            if any([file.endswith(ext) for ext in extensions]):
                full_path = os.path.join(root, file)
                with open(full_path, "r", encoding="utf-8") as f:
                    content = f.read()
                    file_summary = get_first_summary_from_contents(content)
                    snippets.append({
                        "content": content,
                        "metadata": {
                            "filename": file,
                            "filepath": full_path,
                            "filesize": len(content),
                            "project": os.path.basename(root),
                            'summary': file_summary
                        }
                    })
    return snippets


CODE_PATH = '../data/terraform-examples/aws/'


snippets = load_snippets(CODE_PATH)
snippets

# %% [markdown]
# ## 2. Creando chunks de código usando una estrategia híbrida
#
# Usando una librería para detectar bloques de código se puede dividir los archivos de código en pedazos o *chunks*. Podría servir para mantener significado semántico a cada pedazo.

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

splitter = RecursiveCharacterTextSplitter(
    chunk_size=550,
    chunk_overlap=50,
    separators=["\nresource", "\nmodule", "\nvariable", "\noutput", "\n"]
)

def chunk_snippets(snippets):
    chunked_docs = []
    for snippet in snippets:
        chunks = splitter.split_text(snippet["content"])
        for chunk in chunks:
            # getting some metadata for each chunk
            metadata = snippet["metadata"].copy()
            chunk_summary = get_first_summary_from_contents(
                chunk,
                ['# summary:', '# ', '// ', '# resumen:'])
            chunk_summary += f"{metadata['summary']} > {chunk_summary}"
            
            chunked_docs.append({
                "content": chunk,
                "metadata": metadata
            })
    return chunked_docs

chunk_snippets = chunk_snippets(snippets)
chunk_snippets
# Out:
# [{'content': '## AWS Examples\n\nExamples of AWS Terraform modules.\n\nEach module corresponds to a module that uses that resource, eg `aws_vpc`.',
#   'metadata': {'filename': 'README.md',
#    'filepath': '../data/terraform-examples/aws/README.md',
#    'filesize': 130,
#    'project': '',
#    'summary': ''}},
#  {'content': '#!/bin/bash\n../../../bin/apply.sh aws',
#   'metadata': {'filename': 'run.sh',
#    'filepath': '../data/terraform-examples/aws/aws_dynamodb_table_item/simple/run.sh',
#    'filesize': 38,
#    'project': 'simple',
#    'summary': ''}},
#  {'content': '#!/bin/bash\n../../../bin/destroy.sh aws',
#   'metadata': {'filename': 'destroy.sh',
#    'filepath': '../data/terraform-examples/aws/aws_dynamodb_table_item/simple/destroy.sh',
#    'filesize': 40,
#    'project': 'simple',
#    'summary': ''}},
#  {'content': '# Summary: Create a table with one item in AWS DynamoDB\n\n# Documentation: https://www.terraform.io/docs/language/settings/index.html\nterraform {\n  required_version = ">= 1.0.0"\n  required_providers {\n    aws = {\n      source  = "hashicorp/aws"\n      version = "~> 3.38"\n    }\n  }\n}\n\n# Documentation: https://www.terraform.io/docs/language/providers/requirements.html\nprovider "aws" {\n  region  = "us-east-1"\n  profile = "terraform-examples"\n  default_tags {\n    tags = {\n      cs_terraform_examples = "aws_dynamodb_table_item/simple"\n    }\n  }\n}',
#   'metadata': {'filename': 'main.tf',
#    'filepath': '../data/terraform-examples/aws/aws_dynamodb_table_item/simple/main.tf',
#    'filesize': 1917,
#    'project': 'simple',
#    'summary': 'Create a table with one item in AWS DynamoDB'}},
#  {'content': '}\n  }\n}\n\n# Documentation: https://www.terraform.io/docs/language/values/variables.html',
#   'metadata': {'filename': 'main.tf',
#    'filepath': '../data/terraform-examples/aws/aws_dynamodb_table_item/simple/main.tf',
#    'filesize': 1917,
#    'project': 'simple',
#    'summary': 'Create a table with one item in AWS DynamoDB'}},
#  {'content': 'variable "changeme_item_hash_key" {\n  description = "the hash key that\'s also defined as an attribute"\n  default     = "example_hash_key"\n}\n\n# Documentation: https://registry.terraform.io/providers/hashicorp/aws/latest/docs/resources/dynamodb_table_item',
#   'metadata': {'filename': 'main.tf',
#    'filepath': '../data/terraform-examples/aws/aws_dynamodb_table_item/simple/main.tf',
#    'filesize': 1917,
#    'project': 'simple',
#    'summary': 'Create a table with one item in AWS DynamoDB'}},
#  {'content': 'resource "aws_dynamodb_table_item" "changeme_dynamodb_table_item" {\n  table_name = aws_dynamodb_table.changeme_aws_dynamodb_table_resource.name\n  hash_key   = aws_dynamodb_table.changeme_aws_dynamodb_table_resource.hash_key\n\n  item = <<ITEM\n{\n  "example_hash_key": {"S": "something"},\n  "example_attribute": {"N": "11111"}\n}\nITEM\n}\n\n# Documentation: https://registry.terraform.io/providers/hashicorp/aws/latest/docs/resources/dynamodb_table',
#   'metadata': {'filename': 'main.tf',
#    'filepath': '../data/terraform-examples/aws/aws_dynamodb_table_item/simple/main.tf',
#    'filesize': 1917,
#    'project': 'simple',
#    'summary': 'Create a table with one item in AWS DynamoDB'}},
#  {'content': 'resource "aws_dynamodb_table" "changeme_aws_dynamodb_table_resource" {\n  name           = "changeme_dynamodb_table_name" # Explanation: the table\'s name, which needs to be unique to a region\n  read_capacity  = 10                             # Explanation: the number of read units for the table\n  write_capacity = 10                             # Explanation: the number of write units for the table\n  hash_key       = var.changeme_item_hash_key\n\n  attribute {',
#   'metadata': {'filename': 'main.tf',
#    'filepath': '../data/terraform-examples/aws/aws_dynamodb_table_item/simple/main.tf',
#    'filesize': 1917,
#    'project': 'simple',
#    'summary': 'Create a table with one item in AWS DynamoDB'}},
#  {'content': 'attribute {\n    name = var.changeme_item_hash_key # Explanation: the attribute must be of type [S]tring, [N]umber, or [B]inary\n    type = "S"\n  }\n}',
#   'metadata': {'filename': 'main.tf',
#    'filepath': '../data/terraform-examples/aws/aws_dynamodb_table_item/simple/main.tf',
#    'filesize': 1917,
#    'project': 'simple',
#    'summary': 'Create a table with one item in AWS DynamoDB'}},
#  {'content': '#!/bin/bash\n../../../bin/destroy.sh aws',
#   'metadata': {'filename': 'destroy.sh',
#    'filepath': '../data/terraform-examples/aws/aws_vpc/simple/destroy.sh',
#    'filesize': 40,
#    'project': 'simple',
#    'summary': ''}},
#  {'content': '#!/bin/bash\n\ncd "${0%/*}" || exit 1\n\necho \'================================================================================\'\necho "In $(pwd), running $0"\necho \'================================================================================\'\n\nINIT_DONE="N"\nVPC_IDS=$(aws ec2 describe-vpcs | jq -r \'.Vpcs[] | select(.Tags and .Tags[].Key=="cs_terraform_examples" and .Tags[].Value=="aws_vpc/simple") | .VpcId\')\ncount=0\nfor vpc_id in $VPC_IDS\ndo\n  if [[ ${INIT_DONE} == "N" ]]\n  then\n    INIT_DONE="Y"\n    terraform init\n  fi',
#   'metadata': {'filename': 'import.sh',
#    'filepath': '../data/terraform-examples/aws/aws_vpc/simple/import.sh',
#    'filesize': 606,
#    'project': 'simple',
#    'summary': ''}},
#  {'content': 'then\n    INIT_DONE="Y"\n    terraform init\n  fi\n  terraform import "aws_vpc.changeme_aws_vpc_simple" "$vpc_id"\n  ((count++))\ndone',
#   'metadata': {'filename': 'import.sh',
#    'filepath': '../data/terraform-examples/aws/aws_vpc/simple/import.sh',
#    'filesize': 606,
#    'project': 'simple',
#    'summary': ''}},
#  {'content': '#!/bin/bash\n../../../bin/apply.sh aws',
#   'metadata': {'filename': 'run.sh',
#    'filepath': '../data/terraform-examples/aws/aws_vpc/simple/run.sh',
#    'filesize': 38,
#    'project': 'simple',
#    'summary': ''}},
#  {'content': '# Summary: Create an AWS VPC\n\n# Documentation: https://www.terraform.io/docs/language/settings/index.html\nterraform {\n  required_version = ">= 1.0.0"\n  required_providers {\n    aws = {\n      source  = "hashicorp/aws"\n      version = "~> 3.38"\n    }\n  }\n}\n\n# Documentation: https://www.terraform.io/docs/language/providers/requirements.html\nprovider "aws" {\n  region = "us-east-1"\n  default_tags {\n    tags = {\n      cs_terraform_examples = "aws_vpc/simple"\n    }\n  }\n}',
#   'metadata': {'filename': 'main.tf',
#    'filepath': '../data/terraform-examples/aws/aws_vpc/simple/main.tf',
#    'filesize': 648,
#    'project': 'simple',
#    'summary': 'Create an AWS VPC'}},
#  {'content': '}\n  }\n}\n\n# Documentation: https://registry.terraform.io/providers/hashicorp/aws/latest/docs/data-sources/vpc',
#   'metadata': {'filename': 'main.tf',
#    'filepath': '../data/terraform-examples/aws/aws_vpc/simple/main.tf',
#    'filesize': 648,
#    'project': 'simple',
#    'summary': 'Create an AWS VPC'}},
#  {'content': 'resource "aws_vpc" "changeme_aws_vpc_simple" {\n  cidr_block = "10.1.0.0/16"\n}',
#   'metadata': {'filename': 'main.tf',
#    'filepath': '../data/terraform-examples/aws/aws_vpc/simple/main.tf',
#    'filesize': 648,
#    'project': 'simple',
#    'summary': 'Create an AWS VPC'}},
#  {'content': '#!/bin/bash\n\ncd "${0%/*}" || exit 1\n\necho \'================================================================================\'\necho "In $(pwd), running $0"\necho \'================================================================================\'\n\nINIT_DONE="N"\nVPC_IDS=$(aws ec2 describe-vpcs | jq -r \'.Vpcs[] | select(.Tags and .Tags[].Key=="cs_terraform_examples" and .Tags[].Value=="aws_vpc/count") | .VpcId\')\ncount=0\nfor vpc_id in $VPC_IDS\ndo\n  if [[ ${INIT_DONE} == "N" ]]\n  then\n    INIT_DONE="Y"\n    terraform init\n  fi',
#   'metadata': {'filename': 'import.sh',
#    'filepath': '../data/terraform-examples/aws/aws_vpc/count/import.sh',
#    'filesize': 614,
#    'project': 'count',
#    'summary': ''}},
#  {'content': 'then\n    INIT_DONE="Y"\n    terraform init\n  fi\n  terraform import "aws_vpc.changeme_aws_vpc_count[${count}]" "$vpc_id"\n  ((count++))\ndone',
#   'metadata': {'filename': 'import.sh',
#    'filepath': '../data/terraform-examples/aws/aws_vpc/count/import.sh',
#    'filesize': 614,
#    'project': 'count',
#    'summary': ''}},
#  {'content': '# Summary: Example of \'for\' block\n\n# Documentation: https://www.terraform.io/docs/language/settings/index.html\nterraform {\n  required_version = ">= 1.0.0"\n  required_providers {\n    aws = {\n      source  = "hashicorp/aws"\n      version = "~> 3.38"\n    }\n  }\n}\n\n# Documentation: https://www.terraform.io/docs/language/providers/requirements.html\nprovider "aws" {\n  region = "us-east-1"\n  default_tags {\n    tags = {\n      cs_terraform_examples = "aws_vpc/count"\n    }\n  }\n}',
#   'metadata': {'filename': 'main.tf',
#    'filepath': '../data/terraform-examples/aws/aws_vpc/count/main.tf',
#    'filesize': 1149,
#    'project': 'count',
#    'summary': "Example of 'for' block"}},
#  {'content': '}\n  }\n}\n\n# Documentation: https://registry.terraform.io/providers/hashicorp/aws/latest/docs/data-sources/vpc',
#   'metadata': {'filename': 'main.tf',
#    'filepath': '../data/terraform-examples/aws/aws_vpc/count/main.tf',
#    'filesize': 1149,
#    'project': 'count',
#    'summary': "Example of 'for' block"}},
#  {'content': 'resource "aws_vpc" "changeme_aws_vpc_count" {\n  count      = 3\n  cidr_block = format("172.%d.0.0/16", 16 + count.index)\n}\n\n# Documentation: https://www.terraform.io/docs/language/values/outputs.html\noutput "changeme_aws_vpc_count_splat" {\n  value = aws_vpc.changeme_aws_vpc_count[*].cidr_block\n}\n\n# Documentation: https://www.terraform.io/docs/language/values/outputs.html',
#   'metadata': {'filename': 'main.tf',
#    'filepath': '../data/terraform-examples/aws/aws_vpc/count/main.tf',
#    'filesize': 1149,
#    'project': 'count',
#    'summary': "Example of 'for' block"}},
#  {'content': 'output "changeme_aws_vpc_count_for" {\n  # Documentation: https://www.terraform.io/docs/language/expressions/for.html\n  value = [\n    for vpc in aws_vpc.changeme_aws_vpc_count :\n    vpc.cidr_block\n  ]\n}',
#   'metadata': {'filename': 'main.tf',
#    'filepath': '../data/terraform-examples/aws/aws_vpc/count/main.tf',
#    'filesize': 1149,
#    'project': 'count',
#    'summary': "Example of 'for' block"}},
#  {'content': '#!/bin/bash\n../../../bin/apply.sh aws',
#   'metadata': {'filename': 'run.sh',
#    'filepath': '../data/terraform-examples/aws/aws_vpc/count/run.sh',
#    'filesize': 38,
#    'project': 'count',
#    'summary': ''}},
#  {'content': '#!/bin/bash\n../../../bin/destroy.sh aws',
#   'metadata': {'filename': 'destroy.sh',
#    'filepath': '../data/terraform-examples/aws/aws_vpc/count/destroy.sh',
#    'filesize': 40,
#    'project': 'count',
#    'summary': ''}},
#  {'content': '#!/bin/bash\n../../../bin/apply.sh aws',
#   'metadata': {'filename': 'run.sh',
#    'filepath': '../data/terraform-examples/aws/aws_vpc/for/run.sh',
#    'filesize': 38,
#    'project': 'for',
#    'summary': ''}},
#  {'content': '# Summary: Simple example of a \'for\' expression in Terraform\n\n# Documentation: https://www.terraform.io/docs/language/settings/index.html\nterraform {\n  required_version = ">= 1.0.0"\n  required_providers {\n    aws = {\n      source  = "hashicorp/aws"\n      version = "~> 3.38"\n    }\n  }\n}\n\n# Documentation: https://www.terraform.io/docs/language/providers/requirements.html\nprovider "aws" {\n  region = "us-east-1"\n  default_tags {\n    tags = {\n      cs_terraform_examples = "aws_vpc/for"\n    }\n  }\n}',
#   'metadata': {'filename': 'main.tf',
#    'filepath': '../data/terraform-examples/aws/aws_vpc/for/main.tf',
#    'filesize': 1078,
#    'project': 'for',
#    'summary': "Simple example of a 'for' expression in Terraform"}},
#  {'content': '}\n  }\n}\n\n# Documentation: https://registry.terraform.io/providers/hashicorp/aws/latest/docs/resources/vpc',
#   'metadata': {'filename': 'main.tf',
#    'filepath': '../data/terraform-examples/aws/aws_vpc/for/main.tf',
#    'filesize': 1078,
#    'project': 'for',
#    'summary': "Simple example of a 'for' expression in Terraform"}},
#  {'content': 'resource "aws_vpc" "changeme_aws_vpc_for" {\n  # Documentation: https://www.terraform.io/docs/language/meta-arguments/count.html\n  count      = 3\n  cidr_block = format("172.%d.0.0/16", 16 + count.index)\n}\n\n# Documentation: https://www.terraform.io/docs/language/values/outputs.html\noutput "changeme_aws_vpc_for_output" {\n  # Documentation: https://www.terraform.io/docs/language/expressions/for.html\n  value = [\n    for vpc in aws_vpc.changeme_aws_vpc_for :\n    vpc.cidr_block\n  ]\n}',
#   'metadata': {'filename': 'main.tf',
#    'filepath': '../data/terraform-examples/aws/aws_vpc/for/main.tf',
#    'filesize': 1078,
#    'project': 'for',
#    'summary': "Simple example of a 'for' expression in Terraform"}},
#  {'content': '#!/bin/bash\n../../../bin/destroy.sh aws',
#   'metadata': {'filename': 'destroy.sh',
#    'filepath': '../data/terraform-examples/aws/aws_vpc/for/destroy.sh',
#    'filesize': 40,
#    'project': 'for',
#    'summary': ''}},
#  {'content': '#!/bin/bash\n\ncd "${0%/*}" || exit 1\n\necho \'================================================================================\'\necho "In $(pwd), running $0"\necho \'================================================================================\'\n\nINIT_DONE="N"\nVPC_IDS=$(aws ec2 describe-vpcs | jq -r \'.Vpcs[] | select(.Tags and .Tags[].Key=="cs_terraform_examples" and .Tags[].Value=="aws_vpc/for") | .VpcId\')\ncount=0\nfor vpc_id in $VPC_IDS\ndo\n  if [[ ${INIT_DONE} == "N" ]]\n  then\n    INIT_DONE="Y"\n    terraform init\n  fi',
#   'metadata': {'filename': 'import.sh',
#    'filepath': '../data/terraform-examples/aws/aws_vpc/for/import.sh',
#    'filesize': 610,
#    'project': 'for',
#    'summary': ''}},
#  {'content': 'then\n    INIT_DONE="Y"\n    terraform init\n  fi\n  terraform import "aws_vpc.changeme_aws_vpc_for[${count}]" "$vpc_id"\n  ((count++))\ndone',
#   'metadata': {'filename': 'import.sh',
#    'filepath': '../data/terraform-examples/aws/aws_vpc/for/import.sh',
#    'filesize': 610,
#    'project': 'for',
#    'summary': ''}},
#  {'content': '# Summary: Uses the \'count\' feature to create multiple EC2 instances.\nterraform {\n  required_version = ">= 1.0.0"\n  required_providers {\n    aws = {\n      source  = "hashicorp/aws"\n      version = "~> 3.38"\n    }\n  }\n}\n\n# Documentation: https://www.terraform.io/docs/language/providers/requirements.html\nprovider "aws" {\n  region = "us-east-1"\n  default_tags {\n    tags = {\n      cs_terraform_examples = "aws_vpc/splat"\n    }\n  }\n}\n\n# Documentation: https://registry.terraform.io/providers/hashicorp/aws/latest/docs/resources/vpc',
#   'metadata': {'filename': 'main.tf',
#    'filepath': '../data/terraform-examples/aws/aws_vpc/splat/main.tf',
#    'filesize': 1010,
#    'project': 'splat',
#    'summary': "Uses the 'count' feature to create multiple EC2 instances."}},
#  {'content': 'resource "aws_vpc" "changeme_aws_vpc_splat" {\n  # Documentation: # Documentation: https://www.terraform.io/docs/language/meta-arguments/count.html\n  count      = 3\n  cidr_block = format("172.%d.0.0/16", 16 + count.index)\n}\n\n# Documentation: https://www.terraform.io/docs/language/values/outputs.html\noutput "changeme_cidr_block_full_splat" {\n  # Documentation: https://www.terraform.io/docs/language/expressions/splat.html\n  value = aws_vpc.changeme_aws_vpc_splat[*].cidr_block\n}',
#   'metadata': {'filename': 'main.tf',
#    'filepath': '../data/terraform-examples/aws/aws_vpc/splat/main.tf',
#    'filesize': 1010,
#    'project': 'splat',
#    'summary': "Uses the 'count' feature to create multiple EC2 instances."}},
#  {'content': '#!/bin/bash\n../../../bin/destroy.sh aws',
#   'metadata': {'filename': 'destroy.sh',
#    'filepath': '../data/terraform-examples/aws/aws_vpc/splat/destroy.sh',
#    'filesize': 40,
#    'project': 'splat',
#    'summary': ''}},
#  {'content': '#!/bin/bash\n\ncd "${0%/*}" || exit 1\n\necho \'================================================================================\'\necho "In $(pwd), running $0"\necho \'================================================================================\'\n\nINIT_DONE="N"\nVPC_IDS=$(aws ec2 describe-vpcs | jq -r \'.Vpcs[] | select(.Tags and .Tags[].Key=="cs_terraform_examples" and .Tags[].Value=="aws_vpc/splat") | .VpcId\')\ncount=0\nfor vpc_id in $VPC_IDS\ndo\n  if [[ ${INIT_DONE} == "N" ]]\n  then\n    INIT_DONE="Y"\n    terraform init\n  fi',
#   'metadata': {'filename': 'import.sh',
#    'filepath': '../data/terraform-examples/aws/aws_vpc/splat/import.sh',
#    'filesize': 614,
#    'project': 'splat',
#    'summary': ''}},
#  {'content': 'then\n    INIT_DONE="Y"\n    terraform init\n  fi\n  terraform import "aws_vpc.changeme_aws_vpc_splat[${count}]" "$vpc_id"\n  ((count++))\ndone',
#   'metadata': {'filename': 'import.sh',
#    'filepath': '../data/terraform-examples/aws/aws_vpc/splat/import.sh',
#    'filesize': 614,
#    'project': 'splat',
#    'summary': ''}},
#  {'content': '#!/bin/bash\n../../../bin/apply.sh aws',
#   'metadata': {'filename': 'run.sh',
#    'filepath': '../data/terraform-examples/aws/aws_vpc/splat/run.sh',
#    'filesize': 38,
#    'project': 'splat',
#    'summary': ''}},
#  {'content': '# Summary: Create an IAM user with IAM access key to allow API requests to be made as an IAM user.\n\n# Documentation: https://www.terraform.io/docs/language/settings/index.html\nterraform {\n  required_version = ">= 1.0.0"\n  required_providers {\n    aws = {\n      source  = "hashicorp/aws"\n      version = "~> 3.38"\n    }\n  }\n}\n\n# Documentation: https://www.terraform.io/docs/language/providers/requirements.html\nprovider "aws" {\n  region = "us-east-1"\n  default_tags {\n    tags = {\n      cs_terraform_examples = "aws_iam/users"\n    }\n  }\n}',
#   'metadata': {'filename': 'main.tf',
#    'filepath': '../data/terraform-examples/aws/aws_iam/users/main.tf',
#    'filesize': 1353,
#    'project': 'users',
#    'summary': 'Create an IAM user with IAM access key to allow API requests to be made as an IAM user.'}},
#  {'content': '}\n  }\n}\n\n# Documentation: https://registry.terraform.io/providers/hashicorp/aws/latest/docs/resources/iam_user',
#   'metadata': {'filename': 'main.tf',
#    'filepath': '../data/terraform-examples/aws/aws_iam/users/main.tf',
#    'filesize': 1353,
#    'project': 'users',
#    'summary': 'Create an IAM user with IAM access key to allow API requests to be made as an IAM user.'}},
#  {'content': 'resource "aws_iam_user" "changeme_iam_user" {\n  name = "changeme-iam-user-name"\n}\n\n# Documentation: https://registry.terraform.io/providers/hashicorp/aws/latest/docs/resources/iam_access_key\nresource "aws_iam_access_key" "changeme_iam_user" {\n  user = aws_iam_user.changeme_iam_user.name\n}\n\n# Documentation: https://registry.terraform.io/providers/hashicorp/aws/latest/docs/resources/iam_group_policy',
#   'metadata': {'filename': 'main.tf',
#    'filepath': '../data/terraform-examples/aws/aws_iam/users/main.tf',
#    'filesize': 1353,
#    'project': 'users',
#    'summary': 'Create an IAM user with IAM access key to allow API requests to be made as an IAM user.'}},
#  {'content': 'resource "aws_iam_user_policy" "changeme_iam_group_policy_admin" {\n  name = "changeme-iam-group-policy-admin"\n  user = aws_iam_user.changeme_iam_user.name\n\n  policy = <<EOF\n{\n  "Version": "2012-10-17",\n  "Statement": [\n    {\n      "Effect": "Allow",\n      "Action": "*",\n      "Resource": "*"\n    }\n  ]\n}\nEOF\n}',
#   'metadata': {'filename': 'main.tf',
#    'filepath': '../data/terraform-examples/aws/aws_iam/users/main.tf',
#    'filesize': 1353,
#    'project': 'users',
#    'summary': 'Create an IAM user with IAM access key to allow API requests to be made as an IAM user.'}},
#  {'content': '#!/bin/bash\n../../../bin/destroy.sh aws',
#   'metadata': {'filename': 'destroy.sh',
#    'filepath': '../data/terraform-examples/aws/aws_iam/users/destroy.sh',
#    'filesize': 40,
#    'project': 'users',
#    'summary': ''}},
#  {'content': '#!/bin/bash\n../../../bin/apply.sh aws',
#   'metadata': {'filename': 'run.sh',
#    'filepath': '../data/terraform-examples/aws/aws_iam/users/run.sh',
#    'filesize': 38,
#    'project': 'users',
#    'summary': ''}},
#  {'content': '# Summary: Create a two users in two groups\n\n# Documentation: https://www.terraform.io/docs/language/settings/index.html\nterraform {\n  required_version = ">= 1.0.0"\n  required_providers {\n    aws = {\n      source  = "hashicorp/aws"\n      version = "~> 3.38"\n    }\n  }\n}\n\n# Documentation: https://www.terraform.io/docs/language/providers/requirements.html\nprovider "aws" {\n  region = "us-east-1"\n  default_tags {\n    tags = {\n      cs_terraform_examples = "aws_iam/groups"\n    }\n  }\n}',
#   'metadata': {'filename': 'main.tf',
#    'filepath': '../data/terraform-examples/aws/aws_iam/groups/main.tf',
#    'filesize': 3202,
#    'project': 'groups',
#    'summary': 'Create a two users in two groups'}},
#  {'content': '}\n  }\n}\n\n# Documentation: https://www.terraform.io/docs/language/values/variables.html',
#   'metadata': {'filename': 'main.tf',
#    'filepath': '../data/terraform-examples/aws/aws_iam/groups/main.tf',
#    'filesize': 3202,
#    'project': 'groups',
#    'summary': 'Create a two users in two groups'}},
#  {'content': 'variable "changeme_iam_groups_groups" {\n  type = list(any)\n  default = [\n    "Dev",\n    "Infra"\n  ]\n}\n\n# Documentation: https://www.terraform.io/docs/language/values/variables.html\nvariable "changeme_iam_groups_users" {\n  type = map(any)\n  default = {\n    "jane.doe" = {\n      "groups" = [\n        "Dev"\n      ],\n    },\n    "john.doe" = {\n      "groups" = [\n        "Infra"\n      ],\n    }\n  }\n}\n\n# Documentation: https://registry.terraform.io/providers/hashicorp/aws/latest/docs/resources/iam_group',
#   'metadata': {'filename': 'main.tf',
#    'filepath': '../data/terraform-examples/aws/aws_iam/groups/main.tf',
#    'filesize': 3202,
#    'project': 'groups',
#    'summary': 'Create a two users in two groups'}},
#  {'content': 'resource "aws_iam_group" "changeme_iam_groups_groups" {\n  count = length(var.changeme_iam_groups_groups)\n  name  = var.changeme_iam_groups_groups[count.index]\n}\n\n# Documentation: https://registry.terraform.io/providers/hashicorp/aws/latest/docs/resources/iam_group_policy_attachment',
#   'metadata': {'filename': 'main.tf',
#    'filepath': '../data/terraform-examples/aws/aws_iam/groups/main.tf',
#    'filesize': 3202,
#    'project': 'groups',
#    'summary': 'Create a two users in two groups'}},
#  {'content': 'resource "aws_iam_group_policy_attachment" "changeme_iam_group_policy_attachment_administrators" {\n  group      = aws_iam_group.changeme_iam_groups_groups[1].name\n  policy_arn = "arn:aws:iam::aws:policy/AdministratorAccess"\n}\n\n# Documentation: https://registry.terraform.io/providers/hashicorp/aws/latest/docs/resources/iam_group_policy',
#   'metadata': {'filename': 'main.tf',
#    'filepath': '../data/terraform-examples/aws/aws_iam/groups/main.tf',
#    'filesize': 3202,
#    'project': 'groups',
#    'summary': 'Create a two users in two groups'}},
#  {'content': 'resource "aws_iam_group_policy" "changeme_iam_group_policy_dev" {\n  name   = "changeme-iam-group-policy-dev"\n  group  = aws_iam_group.changeme_iam_groups_groups[1].id\n  policy = <<EOF\n{\n  "Version": "2012-10-17",\n  "Statement": [\n    {\n      "Effect": "Allow",\n      "Action": "*",\n      "Resource": "*"\n    }\n  ]\n}\nEOF\n}\n\n# Documentation: https://registry.terraform.io/providers/hashicorp/aws/latest/docs/resources/iam_group_policy',
#   'metadata': {'filename': 'main.tf',
#    'filepath': '../data/terraform-examples/aws/aws_iam/groups/main.tf',
#    'filesize': 3202,
#    'project': 'groups',
#    'summary': 'Create a two users in two groups'}},
#  {'content': 'resource "aws_iam_group_policy" "changeme_iam_group_policy_dev_assumerole" {\n  name   = "changeme-iam-group-policy-devsecops-assumerole"\n  group  = aws_iam_group.changeme_iam_groups_groups[1].id\n  policy = <<EOF\n{\n  "Version": "2012-10-17",\n  "Statement": [\n    {\n      "Effect": "Allow",\n      "Action": "*",\n      "Resource": "*"\n    }\n  ]\n}\nEOF\n}\n\n# Documentation: https://registry.terraform.io/providers/hashicorp/aws/latest/docs/resources/iam_user',
#   'metadata': {'filename': 'main.tf',
#    'filepath': '../data/terraform-examples/aws/aws_iam/groups/main.tf',
#    'filesize': 3202,
#    'project': 'groups',
#    'summary': 'Create a two users in two groups'}},
#  {'content': 'resource "aws_iam_user" "changeme_iam_user_users" {\n  for_each = var.changeme_iam_groups_users\n  name     = each.key\n}\n\n# Documentation: https://registry.terraform.io/providers/hashicorp/aws/latest/docs/resources/iam_user_group_membership',
#   'metadata': {'filename': 'main.tf',
#    'filepath': '../data/terraform-examples/aws/aws_iam/groups/main.tf',
#    'filesize': 3202,
#    'project': 'groups',
#    'summary': 'Create a two users in two groups'}},
#  {'content': 'resource "aws_iam_user_group_membership" "changeme_iam_user_group_membership_user_groups" {\n  for_each = var.changeme_iam_groups_users\n  user     = each.key\n  groups   = each.value["groups"]\n  # This manual dependency is required, else Terraform complains the users do not exist yet.\n  depends_on = [\n    aws_iam_user.changeme_iam_user_users,\n    aws_iam_group.changeme_iam_groups_groups\n  ]\n}',
#   'metadata': {'filename': 'main.tf',
#    'filepath': '../data/terraform-examples/aws/aws_iam/groups/main.tf',
#    'filesize': 3202,
#    'project': 'groups',
#    'summary': 'Create a two users in two groups'}},
#  {'content': '#!/bin/bash\n../../../bin/destroy.sh aws',
#   'metadata': {'filename': 'destroy.sh',
#    'filepath': '../data/terraform-examples/aws/aws_iam/groups/destroy.sh',
#    'filesize': 40,
#    'project': 'groups',
#    'summary': ''}},
#  {'content': '#!/bin/bash\n../../../bin/apply.sh aws',
#   'metadata': {'filename': 'run.sh',
#    'filepath': '../data/terraform-examples/aws/aws_iam/groups/run.sh',
#    'filesize': 38,
#    'project': 'groups',
#    'summary': ''}},
#  {'content': '#!/bin/bash\n../../../bin/destroy.sh aws',
#   'metadata': {'filename': 'destroy.sh',
#    'filepath': '../data/terraform-examples/aws/aws_security_group/ssh/destroy.sh',
#    'filesize': 40,
#    'project': 'ssh',
#    'summary': ''}},
#  {'content': '# Summary: Security group that allows SSH connections\n\n#\xa0https://www.terraform.io/docs/language/settings/index.html\nterraform {\n  required_version = ">= 1.0.0"\n  required_providers {\n    aws = {\n      source  = "hashicorp/aws"\n      version = "~> 3.38"\n    }\n  }\n}\n\n# Documentation: https://www.terraform.io/docs/language/providers/requirements.html\nprovider "aws" {\n  region = "us-east-1"\n  default_tags {\n    tags = {\n      cs_terraform_examples = "aws_security_group/ssh"\n    }\n  }\n}',
#   'metadata': {'filename': 'main.tf',
#    'filepath': '../data/terraform-examples/aws/aws_security_group/ssh/main.tf',
#    'filesize': 877,
#    'project': 'ssh',
#    'summary': 'Security group that allows SSH connections'}},
#  {'content': '}\n  }\n}\n\n# Documentation: https://registry.terraform.io/providers/hashicorp/aws/latest/docs/resources/security_group',
#   'metadata': {'filename': 'main.tf',
#    'filepath': '../data/terraform-examples/aws/aws_security_group/ssh/main.tf',
#    'filesize': 877,
#    'project': 'ssh',
#    'summary': 'Security group that allows SSH connections'}},
#  {'content': 'resource "aws_security_group" "changeme_aws_security_group_ssh" {\n  name        = "changeme_aws_security_group_ssh_name"\n  description = "Allow SSH inbound traffic"\n  ingress {\n    from_port   = 22\n    to_port     = 22\n    protocol    = "tcp"\n    cidr_blocks = ["0.0.0.0/0"]\n  }\n}',
#   'metadata': {'filename': 'main.tf',
#    'filepath': '../data/terraform-examples/aws/aws_security_group/ssh/main.tf',
#    'filesize': 877,
#    'project': 'ssh',
#    'summary': 'Security group that allows SSH connections'}},
#  {'content': '#!/bin/bash\n../../../bin/apply.sh aws',
#   'metadata': {'filename': 'run.sh',
#    'filepath': '../data/terraform-examples/aws/aws_security_group/ssh/run.sh',
#    'filesize': 38,
#    'project': 'ssh',
#    'summary': ''}},
#  {'content': '#!/bin/bash\n../../../bin/apply.sh aws',
#   'metadata': {'filename': 'run.sh',
#    'filepath': '../data/terraform-examples/aws/aws_security_group/dynamic/run.sh',
#    'filesize': 38,
#    'project': 'dynamic',
#    'summary': ''}},
#  {'content': '#!/bin/bash\n../../../bin/destroy.sh aws',
#   'metadata': {'filename': 'destroy.sh',
#    'filepath': '../data/terraform-examples/aws/aws_security_group/dynamic/destroy.sh',
#    'filesize': 40,
#    'project': 'dynamic',
#    'summary': ''}},
#  {'content': '# Summary: Uses \'dynamic\' to create multiple \'ingress\' blocks within an \'aws_security_group\' resource.\n\n# Documentation: https://www.terraform.io/docs/language/settings/index.html\nterraform {\n  required_version = ">= 1.0.0"\n  required_providers {\n    aws = {\n      source  = "hashicorp/aws"\n      version = "~> 3.38"\n    }\n  }\n}\n\n# Documentation: https://www.terraform.io/docs/language/providers/requirements.html\nprovider "aws" {\n  region = "us-east-1"\n  default_tags {\n    tags = {\n      cs_terraform_examples = "aws_security_group/dynamic"\n    }',
#   'metadata': {'filename': 'main.tf',
#    'filepath': '../data/terraform-examples/aws/aws_security_group/dynamic/main.tf',
#    'filesize': 1269,
#    'project': 'dynamic',
#    'summary': "Uses 'dynamic' to create multiple 'ingress' blocks within an 'aws_security_group' resource."}},
#  {'content': '}\n  }\n}\n\n# Documentation: https://www.terraform.io/docs/language/values/locals.html\nlocals {\n  ports = [80, 443, 8080]\n}\n\n# Documentation: https://registry.terraform.io/providers/hashicorp/aws/latest/docs/resources/security_group',
#   'metadata': {'filename': 'main.tf',
#    'filepath': '../data/terraform-examples/aws/aws_security_group/dynamic/main.tf',
#    'filesize': 1269,
#    'project': 'dynamic',
#    'summary': "Uses 'dynamic' to create multiple 'ingress' blocks within an 'aws_security_group' resource."}},
#  {'content': 'resource "aws_security_group" "changeme_aws_security_group_dynamic" {\n  name = "changeme-aws-security-group-dynamic"\n\n  # Documentation: https://www.terraform.io/docs/language/expressions/dynamic-blocks.html\n  dynamic "ingress" {\n    for_each = local.ports\n    content {\n      description = "changeme-aws-security-group-dynamic-ingress-${ingress.key}"\n      from_port   = ingress.value\n      to_port     = ingress.value\n      protocol    = "tcp"\n      cidr_blocks = ["0.0.0.0/0"]\n    }\n  }\n}',
#   'metadata': {'filename': 'main.tf',
#    'filepath': '../data/terraform-examples/aws/aws_security_group/dynamic/main.tf',
#    'filesize': 1269,
#    'project': 'dynamic',
#    'summary': "Uses 'dynamic' to create multiple 'ingress' blocks within an 'aws_security_group' resource."}},
#  {'content': '#!/bin/bash\n../../../bin/destroy.sh aws',
#   'metadata': {'filename': 'destroy.sh',
#    'filepath': '../data/terraform-examples/aws/aws_security_group/open/destroy.sh',
#    'filesize': 40,
#    'project': 'open',
#    'summary': ''}},
#  {'content': '# Summary: A completely open security group\n\n# Documentation: https://www.terraform.io/docs/language/settings/index.html\nterraform {\n  required_version = ">= 1.0.0"\n  required_providers {\n    aws = {\n      source  = "hashicorp/aws"\n      version = "~> 3.38"\n    }\n  }\n}\n\n# Documentation: https://www.terraform.io/docs/language/providers/requirements.html\nprovider "aws" {\n  region = "us-east-1"\n  default_tags {\n    tags = {\n      cs_terraform_examples = "aws_secrurity_group/open"\n    }\n  }\n}',
#   'metadata': {'filename': 'main.tf',
#    'filepath': '../data/terraform-examples/aws/aws_security_group/open/main.tf',
#    'filesize': 986,
#    'project': 'open',
#    'summary': 'A completely open security group'}},
#  {'content': '}\n  }\n}\n\n# Documentation: https://registry.terraform.io/providers/hashicorp/aws/latest/docs/resources/security_group',
#   'metadata': {'filename': 'main.tf',
#    'filepath': '../data/terraform-examples/aws/aws_security_group/open/main.tf',
#    'filesize': 986,
#    'project': 'open',
#    'summary': 'A completely open security group'}},
#  {'content': 'resource "aws_security_group" "changeme_aws_security_group_open" {\n  name        = "changeme_aws_security_group_open_name"\n  description = "Allow all traffic"\n  ingress {\n    from_port   = 0\n    to_port     = 0\n    protocol    = "-1"\n    cidr_blocks = ["0.0.0.0/0"]\n  }\n\n  egress {\n    from_port   = 0\n    to_port     = 0\n    protocol    = "-1"\n    cidr_blocks = ["0.0.0.0/0"]\n  }\n}',
#   'metadata': {'filename': 'main.tf',
#    'filepath': '../data/terraform-examples/aws/aws_security_group/open/main.tf',
#    'filesize': 986,
#    'project': 'open',
#    'summary': 'A completely open security group'}},
#  {'content': '#!/bin/bash\n../../../bin/apply.sh aws',
#   'metadata': {'filename': 'run.sh',
#    'filepath': '../data/terraform-examples/aws/aws_security_group/open/run.sh',
#    'filesize': 38,
#    'project': 'open',
#    'summary': ''}},
#  {'content': '#!/bin/bash\n\n# source: https://github.com/terraform-providers/terraform-provider-aws/issues/10104\n\nTHUMBPRINT=$(echo | openssl s_client -servername oidc.eks."${1}".amazonaws.com -showcerts -connect oidc.eks."${1}".amazonaws.com:443 2>&- | tac | sed -n \'/-----END CERTIFICATE-----/,/-----BEGIN CERTIFICATE-----/p; /-----BEGIN CERTIFICATE-----/q\' | tac | openssl x509 -fingerprint -noout | sed \'s/://g\' | awk -F= \'{print tolower($2)}\')\nTHUMBPRINT_JSON="{\\"thumbprint\\": \\"${THUMBPRINT}\\"}"\necho "$THUMBPRINT_JSON"',
#   'metadata': {'filename': 'oidc_thumbprint.sh',
#    'filepath': '../data/terraform-examples/aws/aws_eks/fargate/spot_and_fargate/oidc_thumbprint.sh',
#    'filesize': 511,
#    'project': 'spot_and_fargate',
#    'summary': ''}},
#  {'content': '#!/bin/bash\n../../../../bin/apply.sh aws',
#   'metadata': {'filename': 'run.sh',
#    'filepath': '../data/terraform-examples/aws/aws_eks/fargate/spot_and_fargate/run.sh',
#    'filesize': 41,
#    'project': 'spot_and_fargate',
#    'summary': ''}},
#  {'content': '#!/bin/bash\n../../../../bin/destroy.sh aws',
#   'metadata': {'filename': 'destroy.sh',
#    'filepath': '../data/terraform-examples/aws/aws_eks/fargate/spot_and_fargate/destroy.sh',
#    'filesize': 43,
#    'project': 'spot_and_fargate',
#    'summary': ''}},
#  {'content': '# Summary: See README.md\n\n# Documentation: https://www.terraform.io/docs/language/settings/index.html\nterraform {\n  required_version = ">= 1.0.0"\n  required_providers {\n    local = {\n      version = "~> 1.4"\n    }\n    external = {\n      version = "~> 1.2"\n    }\n    kubernetes = {\n      version = "~> 1.10"\n    }\n    aws = {\n      source  = "hashicorp/aws"\n      version = "~> 3.38"\n    }\n  }\n}\n\n# Documentation: https://www.terraform.io/docs/language/providers/requirements.html\nprovider "aws" {\n  region = "us-east-1"\n  default_tags {\n    tags = {',
#   'metadata': {'filename': 'main.tf',
#    'filepath': '../data/terraform-examples/aws/aws_eks/fargate/spot_and_fargate/main.tf',
#    'filesize': 14603,
#    'project': 'spot_and_fargate',
#    'summary': 'See README.md'}},
#  {'content': 'default_tags {\n    tags = {\n      cs_terraform_examples = "aws_eks/fargate/spot_and_fargate"\n    }\n  }\n}\n\n# Documentation: https://www.terraform.io/docs/language/providers/requirements.html\nprovider "kubernetes" {\n  host                   = data.aws_eks_cluster.changeme_spot_and_fargate_eks_cluster_data.endpoint\n  load_config_file       = false\n  cluster_ca_certificate = base64decode(data.aws_eks_cluster.changeme_spot_and_fargate_eks_cluster_data.certificate_authority[0].data)',
#   'metadata': {'filename': 'main.tf',
#    'filepath': '../data/terraform-examples/aws/aws_eks/fargate/spot_and_fargate/main.tf',
#    'filesize': 14603,
#    'project': 'spot_and_fargate',
#    'summary': 'See README.md'}},
#  {'content': 'token                  = data.aws_eks_cluster_auth.changeme_spot_and_fargate_eks_cluster_auth_data.token\n}\n\n# Documentation: https://www.terraform.io/docs/language/values/variables.html',
#   'metadata': {'filename': 'main.tf',
#    'filepath': '../data/terraform-examples/aws/aws_eks/fargate/spot_and_fargate/main.tf',
#    'filesize': 14603,
#    'project': 'spot_and_fargate',
#    'summary': 'See README.md'}},
#  {'content': 'variable "changeme_spot_and_fargate_name" {\n  description = "the name of your stack, e.g. \\"demo\\""\n  default     = "eks-example"\n}\n\n# Documentation: https://www.terraform.io/docs/language/values/variables.html\nvariable "changeme_spot_and_fargate_environment" {\n  description = "the name of your environment, e.g. \\"prod\\""\n  default     = "prod"\n}\n\n# Documentation: https://www.terraform.io/docs/language/values/variables.html',
#   'metadata': {'filename': 'main.tf',
#    'filepath': '../data/terraform-examples/aws/aws_eks/fargate/spot_and_fargate/main.tf',
#    'filesize': 14603,
#    'project': 'spot_and_fargate',
#    'summary': 'See README.md'}},
#  {'content': 'variable "changeme_spot_and_fargate_region" {\n  description = "the AWS region in which resources are created, you must set the availability_zones variable as well if you define this value to something other than the default"\n  default     = "us-east-1"\n}\n\n# Documentation: https://www.terraform.io/docs/language/values/variables.html',
#   'metadata': {'filename': 'main.tf',
#    'filepath': '../data/terraform-examples/aws/aws_eks/fargate/spot_and_fargate/main.tf',
#    'filesize': 14603,
#    'project': 'spot_and_fargate',
#    'summary': 'See README.md'}},
#  {'content': 'variable "changeme_spot_and_fargate_availability_zones" {\n  description = "a comma-separated list of availability zones, defaults to all AZ of the region, if set to something other than the defaults, both private_subnets and public_subnets have to be defined as well"\n  default     = ["us-east-1a", "us-east-1b", "us-east-1c"]\n}\n\n# Documentation: https://www.terraform.io/docs/language/values/variables.html',
#   'metadata': {'filename': 'main.tf',
#    'filepath': '../data/terraform-examples/aws/aws_eks/fargate/spot_and_fargate/main.tf',
#    'filesize': 14603,
#    'project': 'spot_and_fargate',
#    'summary': 'See README.md'}},
#  {'content': 'variable "changeme_spot_and_fargate_cidr" {\n  description = "The CIDR block for the VPC."\n  default     = "10.0.0.0/16"\n}\n\n# Documentation: https://www.terraform.io/docs/language/values/variables.html',
#   'metadata': {'filename': 'main.tf',
#    'filepath': '../data/terraform-examples/aws/aws_eks/fargate/spot_and_fargate/main.tf',
#    'filesize': 14603,
#    'project': 'spot_and_fargate',
#    'summary': 'See README.md'}},
#  {'content': 'variable "changeme_spot_and_fargate_private_subnets" {\n  description = "a list of CIDRs for private subnets in your VPC, must be set if the cidr variable is defined, needs to have as many elements as there are availability zones"\n  default     = ["10.0.0.0/20", "10.0.32.0/20", "10.0.64.0/20"]\n}\n\n# Documentation: https://www.terraform.io/docs/language/values/variables.html',
#   'metadata': {'filename': 'main.tf',
#    'filepath': '../data/terraform-examples/aws/aws_eks/fargate/spot_and_fargate/main.tf',
#    'filesize': 14603,
#    'project': 'spot_and_fargate',
#    'summary': 'See README.md'}},
#  {'content': 'variable "changeme_spot_and_fargate_public_subnets" {\n  description = "a list of CIDRs for public subnets in your VPC, must be set if the cidr variable is defined, needs to have as many elements as there are availability zones"\n  default     = ["10.0.16.0/20", "10.0.48.0/20", "10.0.80.0/20"]\n}\n\n# Documentation: https://www.terraform.io/docs/language/values/variables.html',
#   'metadata': {'filename': 'main.tf',
#    'filepath': '../data/terraform-examples/aws/aws_eks/fargate/spot_and_fargate/main.tf',
#    'filesize': 14603,
#    'project': 'spot_and_fargate',
#    'summary': 'See README.md'}},
#  {'content': 'variable "changeme_spot_and_fargate_k8s_version" {\n  description = "kubernetes version"\n  default     = ""\n}\n\n# Documentation: https://www.terraform.io/docs/language/data-sources/index.html\ndata "aws_eks_cluster" "changeme_spot_and_fargate_eks_cluster_data" {\n  name = aws_eks_cluster.changeme_spot_and_fargate_eks_cluster.id\n}\n\n# Documentation: https://www.terraform.io/docs/language/data-sources/index.html\ndata "aws_eks_cluster_auth" "changeme_spot_and_fargate_eks_cluster_auth_data" {',
#   'metadata': {'filename': 'main.tf',
#    'filepath': '../data/terraform-examples/aws/aws_eks/fargate/spot_and_fargate/main.tf',
#    'filesize': 14603,
#    'project': 'spot_and_fargate',
#    'summary': 'See README.md'}},
#  {'content': 'name = aws_eks_cluster.changeme_spot_and_fargate_eks_cluster.id\n}\n\n# Fetch OIDC provider thumbprint for root CA\n# Documentation: https://www.terraform.io/docs/language/data-sources/index.html\ndata "external" "changeme_external_thumbprint_data" {\n  program    = ["${path.module}/oidc_thumbprint.sh", var.changeme_spot_and_fargate_region]\n  depends_on = [aws_eks_cluster.changeme_spot_and_fargate_eks_cluster]\n}\n\n# Documentation: https://registry.terraform.io/providers/hashicorp/aws/latest/docs/resources/vpc',
#   'metadata': {'filename': 'main.tf',
#    'filepath': '../data/terraform-examples/aws/aws_eks/fargate/spot_and_fargate/main.tf',
#    'filesize': 14603,
#    'project': 'spot_and_fargate',
#    'summary': 'See README.md'}},
#  {'content': 'resource "aws_vpc" "changeme_spot_and_fargate_vpc" {\n  cidr_block           = var.changeme_spot_and_fargate_cidr\n  enable_dns_support   = true\n  enable_dns_hostnames = true\n}\n\n# Documentation: https://registry.terraform.io/providers/hashicorp/aws/latest/docs/resources/internet_gateway\nresource "aws_internet_gateway" "changeme_spot_and_fargate_internet_gateway" {\n  vpc_id = aws_vpc.changeme_spot_and_fargate_vpc.id\n}\n\n# Documentation: https://registry.terraform.io/providers/hashicorp/aws/latest/docs/resources/nat_gateway',
#   'metadata': {'filename': 'main.tf',
#    'filepath': '../data/terraform-examples/aws/aws_eks/fargate/spot_and_fargate/main.tf',
#    'filesize': 14603,
#    'project': 'spot_and_fargate',
#    'summary': 'See README.md'}},
#  {'content': 'resource "aws_nat_gateway" "changeme_spot_and_fargate_nat_gateway" {\n  count         = length(var.changeme_spot_and_fargate_private_subnets)\n  allocation_id = element(aws_eip.changeme_spot_and_fargate_eip.*.id, count.index)\n  subnet_id     = element(aws_subnet.changeme_spot_and_fargate_subnet_public.*.id, count.index)\n  depends_on    = [aws_internet_gateway.changeme_spot_and_fargate_internet_gateway]\n}\n\n# Documentation: https://registry.terraform.io/providers/hashicorp/aws/latest/docs/resources/eip',
#   'metadata': {'filename': 'main.tf',
#    'filepath': '../data/terraform-examples/aws/aws_eks/fargate/spot_and_fargate/main.tf',
#    'filesize': 14603,
#    'project': 'spot_and_fargate',
#    'summary': 'See README.md'}},
#  {'content': 'resource "aws_eip" "changeme_spot_and_fargate_eip" {\n  count = length(var.changeme_spot_and_fargate_private_subnets)\n  vpc   = true\n}\n\n# Documentation: https://registry.terraform.io/providers/hashicorp/aws/latest/docs/resources/subnet',
#   'metadata': {'filename': 'main.tf',
#    'filepath': '../data/terraform-examples/aws/aws_eks/fargate/spot_and_fargate/main.tf',
#    'filesize': 14603,
#    'project': 'spot_and_fargate',
#    'summary': 'See README.md'}},
#  {'content': 'resource "aws_subnet" "changeme_spot_and_fargate_subnet_private" {\n  vpc_id            = aws_vpc.changeme_spot_and_fargate_vpc.id\n  cidr_block        = element(var.changeme_spot_and_fargate_private_subnets, count.index)\n  availability_zone = element(var.changeme_spot_and_fargate_availability_zones, count.index)\n  count             = length(var.changeme_spot_and_fargate_private_subnets)\n}\n\n# Documentation: https://registry.terraform.io/providers/hashicorp/aws/latest/docs/resources/subnet',
#   'metadata': {'filename': 'main.tf',
#    'filepath': '../data/terraform-examples/aws/aws_eks/fargate/spot_and_fargate/main.tf',
#    'filesize': 14603,
#    'project': 'spot_and_fargate',
#    'summary': 'See README.md'}},
#  {'content': 'resource "aws_subnet" "changeme_spot_and_fargate_subnet_public" {\n  vpc_id                  = aws_vpc.changeme_spot_and_fargate_vpc.id\n  cidr_block              = element(var.changeme_spot_and_fargate_public_subnets, count.index)\n  availability_zone       = element(var.changeme_spot_and_fargate_availability_zones, count.index)\n  count                   = length(var.changeme_spot_and_fargate_public_subnets)\n  map_public_ip_on_launch = true\n}',
#   'metadata': {'filename': 'main.tf',
#    'filepath': '../data/terraform-examples/aws/aws_eks/fargate/spot_and_fargate/main.tf',
#    'filesize': 14603,
#    'project': 'spot_and_fargate',
#    'summary': 'See README.md'}},
#  {'content': 'map_public_ip_on_launch = true\n}\n\n# Documentation: https://registry.terraform.io/providers/hashicorp/aws/latest/docs/resources/route_table',
#   'metadata': {'filename': 'main.tf',
#    'filepath': '../data/terraform-examples/aws/aws_eks/fargate/spot_and_fargate/main.tf',
#    'filesize': 14603,
#    'project': 'spot_and_fargate',
#    'summary': 'See README.md'}},
#  {'content': 'resource "aws_route_table" "changeme_spot_and_fargate_route_table_public" {\n  vpc_id = aws_vpc.changeme_spot_and_fargate_vpc.id\n}\n\n# Documentation: https://registry.terraform.io/providers/hashicorp/aws/latest/docs/resources/route',
#   'metadata': {'filename': 'main.tf',
#    'filepath': '../data/terraform-examples/aws/aws_eks/fargate/spot_and_fargate/main.tf',
#    'filesize': 14603,
#    'project': 'spot_and_fargate',
#    'summary': 'See README.md'}},
#  {'content': 'resource "aws_route" "changeme_spot_and_fargate_aws_route_public" {\n  route_table_id         = aws_route_table.changeme_spot_and_fargate_route_table_public.id\n  destination_cidr_block = "0.0.0.0/0"\n  gateway_id             = aws_internet_gateway.changeme_spot_and_fargate_internet_gateway.id\n  timeouts {\n    create = "5m"\n  }\n}\n\n# Documentation: https://registry.terraform.io/providers/hashicorp/aws/latest/docs/resources/route_table',
#   'metadata': {'filename': 'main.tf',
#    'filepath': '../data/terraform-examples/aws/aws_eks/fargate/spot_and_fargate/main.tf',
#    'filesize': 14603,
#    'project': 'spot_and_fargate',
#    'summary': 'See README.md'}},
#  {'content': 'resource "aws_route_table" "changeme_spot_and_fargate_route_table_private" {\n  count  = length(var.changeme_spot_and_fargate_private_subnets)\n  vpc_id = aws_vpc.changeme_spot_and_fargate_vpc.id\n}\n\n# Documentation: https://registry.terraform.io/providers/hashicorp/aws/latest/docs/resources/route',
#   'metadata': {'filename': 'main.tf',
#    'filepath': '../data/terraform-examples/aws/aws_eks/fargate/spot_and_fargate/main.tf',
#    'filesize': 14603,
#    'project': 'spot_and_fargate',
#    'summary': 'See README.md'}},
#  {'content': 'resource "aws_route" "changeme_spot_and_fargate_route_private" {\n  count                  = length(compact(var.changeme_spot_and_fargate_private_subnets))\n  route_table_id         = element(aws_route_table.changeme_spot_and_fargate_route_table_private.*.id, count.index)\n  destination_cidr_block = "0.0.0.0/0"\n  nat_gateway_id         = element(aws_nat_gateway.changeme_spot_and_fargate_nat_gateway.*.id, count.index)\n  timeouts {\n    create = "5m"\n  }\n}',
#   'metadata': {'filename': 'main.tf',
#    'filepath': '../data/terraform-examples/aws/aws_eks/fargate/spot_and_fargate/main.tf',
#    'filesize': 14603,
#    'project': 'spot_and_fargate',
#    'summary': 'See README.md'}},
#  {'content': 'timeouts {\n    create = "5m"\n  }\n}\n\n# Documentation: https://registry.terraform.io/providers/hashicorp/aws/latest/docs/resources/route_table_association',
#   'metadata': {'filename': 'main.tf',
#    'filepath': '../data/terraform-examples/aws/aws_eks/fargate/spot_and_fargate/main.tf',
#    'filesize': 14603,
#    'project': 'spot_and_fargate',
#    'summary': 'See README.md'}},
# ...
#    'summary': ''}},
#  {'content': '# Summary: Remote execution using default expected location of your ssh keys,\n# and setup of provider connection.\n#\n# Note: assumes you have a keypair set up in the location specified in\n#\xa0      `changeme_aws_instance_simple_ssh_access_ssh_private_key_path.default` below.\n#       This has been set to a useful default of `~/.ssh/id_rsa`.\n#       You can retrieve the public IP address by looking at the output of `terraform show`,\n#       eg `terraform show | grep public_ip`.',
#   'metadata': {'filename': 'main.tf',
#    'filepath': '../data/terraform-examples/aws/aws_instance/simple_ssh_access/main.tf',
#    'filesize': 4041,
#    'project': 'simple_ssh_access',
#    'summary': 'Remote execution using default expected location of your ssh keys,'}},
#  {'content': '#       eg `terraform show | grep public_ip`.\n#\xa0      You should then be able to log in with, eg: `ssh -i ~/.ssh/id_rsa ubuntu@<<PUBLIC IP ADDRESS>>`.\n\n# Documentation: https://www.terraform.io/docs/language/settings/index.html\nterraform {\n  required_version = ">= 1.0.0"\n  required_providers {\n    aws = {\n      source  = "hashicorp/aws"\n      version = "~> 3.38"\n    }\n  }\n}\n\n# Documentation: https://www.terraform.io/docs/language/providers/requirements.html\nprovider "aws" {\n  region = "us-east-1"\n  default_tags {\n    tags = {',
#   'metadata': {'filename': 'main.tf',
#    'filepath': '../data/terraform-examples/aws/aws_instance/simple_ssh_access/main.tf',
#    'filesize': 4041,
#    'project': 'simple_ssh_access',
#    'summary': 'Remote execution using default expected location of your ssh keys,'}},
#  {'content': 'default_tags {\n    tags = {\n      cs_terraform_examples = "aws_instance/simple_ssh_access"\n    }\n  }\n}\n\n# Documentation: https://www.terraform.io/docs/language/data-sources/index.html\ndata "aws_vpc" "changeme_aws_simple_ssh_access_vpc_default" {\n  default = true\n}\n\n# Documentation: https://www.terraform.io/docs/language/values/variables.html',
#   'metadata': {'filename': 'main.tf',
#    'filepath': '../data/terraform-examples/aws/aws_instance/simple_ssh_access/main.tf',
#    'filesize': 4041,
#    'project': 'simple_ssh_access',
#    'summary': 'Remote execution using default expected location of your ssh keys,'}},
#  {'content': 'variable "changeme_aws_instance_simple_ssh_access_ssh_private_key_path" {\n  description = "SSH private key file path"\n  default     = "~/.ssh/id_rsa"\n}\n\n# Documentation: https://www.terraform.io/docs/language/values/variables.html\nvariable "changeme_aws_instance_simple_ssh_access_ssh_public_key_path" {\n  description = "SSH public key file path"\n  default     = "~/.ssh/id_rsa.pub"\n}\n\n# Documentation: https://www.terraform.io/docs/language/values/variables.html',
#   'metadata': {'filename': 'main.tf',
#    'filepath': '../data/terraform-examples/aws/aws_instance/simple_ssh_access/main.tf',
#    'filesize': 4041,
#    'project': 'simple_ssh_access',
#    'summary': 'Remote execution using default expected location of your ssh keys,'}},
#  {'content': 'variable "changeme_aws_instance_simple_ssh_access_ssh_username" {\n  description = "Default username built into the AMI"\n  default     = "ubuntu"\n}\n\n# Explanation: Create an SSH key pair for accessing the EC2 instance\n#\n# Documentation: https://registry.terraform.io/providers/hashicorp/aws/latest/docs/resources/key_pair',
#   'metadata': {'filename': 'main.tf',
#    'filepath': '../data/terraform-examples/aws/aws_instance/simple_ssh_access/main.tf',
#    'filesize': 4041,
#    'project': 'simple_ssh_access',
#    'summary': 'Remote execution using default expected location of your ssh keys,'}},
#  {'content': 'resource "aws_key_pair" "changeme_simple_ssh_access_aws_key_pair" {\n  public_key = file(var.changeme_aws_instance_simple_ssh_access_ssh_public_key_path)\n}\n\n# Explanation: Create our default security group to access the instance, over specific protocols\n#\n# Documentation: https://registry.terraform.io/providers/hashicorp/aws/latest/docs/resources/security_group',
#   'metadata': {'filename': 'main.tf',
#    'filepath': '../data/terraform-examples/aws/aws_instance/simple_ssh_access/main.tf',
#    'filesize': 4041,
#    'project': 'simple_ssh_access',
#    'summary': 'Remote execution using default expected location of your ssh keys,'}},
#  {'content': 'resource "aws_security_group" "changeme_simple_ssh_access_security_group" {\n  vpc_id = data.aws_vpc.changeme_aws_simple_ssh_access_vpc_default.id\n}\n\n# Documentation: https://registry.terraform.io/providers/hashicorp/aws/latest/docs/resources/security_group_rule',
#   'metadata': {'filename': 'main.tf',
#    'filepath': '../data/terraform-examples/aws/aws_instance/simple_ssh_access/main.tf',
#    'filesize': 4041,
#    'project': 'simple_ssh_access',
#    'summary': 'Remote execution using default expected location of your ssh keys,'}},
#  {'content': 'resource "aws_security_group_rule" "changeme_simple_ssh_access_security_group_rule_outgoing_any" {\n  security_group_id = aws_security_group.changeme_simple_ssh_access_security_group.id\n  type              = "egress"\n  from_port         = 0\n  to_port           = 0\n  protocol          = "-1"\n  cidr_blocks       = ["0.0.0.0/0"]\n}\n\n# Documentation: https://registry.terraform.io/providers/hashicorp/aws/latest/docs/resources/security_group_rule',
#   'metadata': {'filename': 'main.tf',
#    'filepath': '../data/terraform-examples/aws/aws_instance/simple_ssh_access/main.tf',
#    'filesize': 4041,
#    'project': 'simple_ssh_access',
#    'summary': 'Remote execution using default expected location of your ssh keys,'}},
#  {'content': 'resource "aws_security_group_rule" "changeme_simple_ssh_access_security_group_rule_incoming_ssh" {\n  security_group_id = aws_security_group.changeme_simple_ssh_access_security_group.id\n  type              = "ingress"\n  from_port         = 22\n  to_port           = 22\n  protocol          = "tcp"\n  cidr_blocks       = ["0.0.0.0/0"]\n}\n\n# Documentation: https://registry.terraform.io/providers/hashicorp/aws/latest/docs/resources/instance',
#   'metadata': {'filename': 'main.tf',
#    'filepath': '../data/terraform-examples/aws/aws_instance/simple_ssh_access/main.tf',
#    'filesize': 4041,
#    'project': 'simple_ssh_access',
#    'summary': 'Remote execution using default expected location of your ssh keys,'}},
#  {'content': 'resource "aws_instance" "changeme_simple_ssh_access_aws_instance" {\n  # Documentation: https://www.terraform.io/docs/language/meta-arguments/count.html\n  instance_type          = "t2.nano"\n  ami                    = "ami-0ddbdea833a8d2f0d"\n  key_name               = aws_key_pair.changeme_simple_ssh_access_aws_key_pair.id # the name of the SSH keypair to use for provisioning\n  vpc_security_group_ids = [aws_security_group.changeme_simple_ssh_access_security_group.id]\n}',
#   'metadata': {'filename': 'main.tf',
#    'filepath': '../data/terraform-examples/aws/aws_instance/simple_ssh_access/main.tf',
#    'filesize': 4041,
#    'project': 'simple_ssh_access',
#    'summary': 'Remote execution using default expected location of your ssh keys,'}},
#  {'content': '#!/bin/bash\n../../../bin/destroy.sh aws',
#   'metadata': {'filename': 'destroy.sh',
#    'filepath': '../data/terraform-examples/aws/aws_instance/simple_ssh_access/destroy.sh',
#    'filesize': 40,
#    'project': 'simple_ssh_access',
#    'summary': ''}},
#  {'content': 'To run this:\n\n```\n../../../../bin/apply_aws.sh\n```',
#   'metadata': {'filename': 'README.md',
#    'filepath': '../data/terraform-examples/aws/aws_instance/simple_ssh_access/README.md',
#    'filesize': 51,
#    'project': 'simple_ssh_access',
#    'summary': ''}},
#  {'content': '# Summary: Example of \'for_each\' usage.\n\n# Documentation: https://www.terraform.io/docs/language/settings/index.html\nterraform {\n  required_version = ">= 1.0.0"\n  required_providers {\n    aws = {\n      source  = "hashicorp/aws"\n      version = "~> 3.38"\n    }\n  }\n}\n\n# Documentation: https://www.terraform.io/docs/language/providers/requirements.html\nprovider "aws" {\n  region = "us-east-1"\n  default_tags {\n    tags = {\n      cs_terraform_examples = "aws_instance/for_each"\n    }\n  }\n}',
#   'metadata': {'filename': 'main.tf',
#    'filepath': '../data/terraform-examples/aws/aws_instance/for_each/main.tf',
#    'filesize': 933,
#    'project': 'for_each',
#    'summary': "Example of 'for_each' usage."}},
#  {'content': '}\n  }\n}\n\n# Documentation: https://registry.terraform.io/providers/hashicorp/aws/latest/docs/resources/instance',
#   'metadata': {'filename': 'main.tf',
#    'filepath': '../data/terraform-examples/aws/aws_instance/for_each/main.tf',
#    'filesize': 933,
#    'project': 'for_each',
#    'summary': "Example of 'for_each' usage."}},
#  {'content': 'resource "aws_instance" "changeme_aws_instance_count_foreach" {\n  # Documentation: https://www.terraform.io/docs/language/meta-arguments/for_each.html\n  for_each = {\n    "a" = "1"\n    "b" = "2"\n  }\n\n  tags = {\n    Name = "aws_resource_count_${each.key}${each.value}"\n  }\n  instance_type = "t2.nano"\n  ami           = "ami-0ddbdea833a8d2f0d"\n}',
#   'metadata': {'filename': 'main.tf',
#    'filepath': '../data/terraform-examples/aws/aws_instance/for_each/main.tf',
#    'filesize': 933,
#    'project': 'for_each',
#    'summary': "Example of 'for_each' usage."}},
#  {'content': '#!/bin/bash\n../../../bin/apply.sh aws',
#   'metadata': {'filename': 'run.sh',
#    'filepath': '../data/terraform-examples/aws/aws_instance/for_each/run.sh',
#    'filesize': 38,
#    'project': 'for_each',
#    'summary': ''}},
#  {'content': '#!/bin/bash\n../../../bin/destroy.sh aws',
#   'metadata': {'filename': 'destroy.sh',
#    'filepath': '../data/terraform-examples/aws/aws_instance/for_each/destroy.sh',
#    'filesize': 40,
#    'project': 'for_each',
#    'summary': ''}},
#  {'content': '#!/bin/bash\n../../../bin/destroy.sh aws',
#   'metadata': {'filename': 'destroy.sh',
#    'filepath': '../data/terraform-examples/aws/aws_instance/simple/destroy.sh',
#    'filesize': 40,
#    'project': 'simple',
#    'summary': ''}},
#  {'content': '#!/bin/bash\n../../../bin/apply.sh aws',
#   'metadata': {'filename': 'run.sh',
#    'filepath': '../data/terraform-examples/aws/aws_instance/simple/run.sh',
#    'filesize': 38,
#    'project': 'simple',
#    'summary': ''}},
#  {'content': '# Summary: Simplest example of an aws_instance resource\n#\n# Note: This example simply creates the VM, but does not set up a keypair,\n#       or networking such that you can ssh into it from the internet.\n#       For a more complete example, see `aws/aws_instance/remote_exec/inline`.\n\n# Documentation: https://www.terraform.io/docs/language/settings/index.html\nterraform {\n  required_version = ">= 1.0.0"\n  required_providers {\n    aws = {\n      source  = "hashicorp/aws"\n      version = "~> 3.38"\n    }\n  }\n}',
#   'metadata': {'filename': 'main.tf',
#    'filepath': '../data/terraform-examples/aws/aws_instance/simple/main.tf',
#    'filesize': 961,
#    'project': 'simple',
#    'summary': 'Simplest example of an aws_instance resource'}},
#  {'content': 'version = "~> 3.38"\n    }\n  }\n}\n\n# Documentation: https://www.terraform.io/docs/language/providers/requirements.html\nprovider "aws" {\n  region = "us-east-1"\n  default_tags {\n    tags = {\n      cs_terraform_examples = "aws_instance/simple"\n    }\n  }\n}\n\n# Documentation: https://registry.terraform.io/providers/hashicorp/aws/latest/docs/resources/instance',
#   'metadata': {'filename': 'main.tf',
#    'filepath': '../data/terraform-examples/aws/aws_instance/simple/main.tf',
#    'filesize': 961,
#    'project': 'simple',
#    'summary': 'Simplest example of an aws_instance resource'}},
#  {'content': 'resource "aws_instance" "changeme_aws_resource_simple" {\n  instance_type = "t2.nano"\n  ami           = "ami-0ddbdea833a8d2f0d"\n}',
#   'metadata': {'filename': 'main.tf',
#    'filepath': '../data/terraform-examples/aws/aws_instance/simple/main.tf',
#    'filesize': 961,
#    'project': 'simple',
#    'summary': 'Simplest example of an aws_instance resource'}},
#  {'content': '#!/bin/bash\n../../../bin/destroy.sh aws',
#   'metadata': {'filename': 'destroy.sh',
#    'filepath': '../data/terraform-examples/aws/aws_instance/ami_lookup/destroy.sh',
#    'filesize': 40,
#    'project': 'ami_lookup',
#    'summary': ''}},
#  {'content': '#!/bin/bash\n../../../bin/apply.sh aws',
#   'metadata': {'filename': 'run.sh',
#    'filepath': '../data/terraform-examples/aws/aws_instance/ami_lookup/run.sh',
#    'filesize': 38,
#    'project': 'ami_lookup',
#    'summary': ''}},
#  {'content': '# Summary: Data Source for getting latest getting AMI Linux Imagehttps://docs.aws.amazon.com/AWSEC2/latest/UserGuide/finding-an-ami.html\n\n# Documentation: https://www.tserraform.io/docs/language/settings/index.html\nterraform {\n  required_version = ">= 1.0.0"\n  required_providers {\n    aws = {\n      source  = "hashicorp/aws"\n      version = "~> 3.38"\n    }\n  }\n}\n\n# Documentation: https://www.terraform.io/docs/language/providers/requirements.html\nprovider "aws" {\n  region = "us-east-1"\n  default_tags {\n    tags = {',
#   'metadata': {'filename': 'main.tf',
#    'filepath': '../data/terraform-examples/aws/aws_instance/ami_lookup/main.tf',
#    'filesize': 1744,
#    'project': 'ami_lookup',
#    'summary': 'Data Source for getting latest getting AMI Linux Imagehttps://docs.aws.amazon.com/AWSEC2/latest/UserGuide/finding-an-ami.html'}},
#  {'content': 'default_tags {\n    tags = {\n      cs_terraform_examples = "aws_instance/ami_lookup"\n    }\n  }\n}\n\n# Documentation: https://registry.terraform.io/providers/hashicorp/aws/latest/docs/data-sources/ami\n# Explanation: Get most_recent version of Ubuntu Image \ndata "aws_ami" "changeme_aws_ami" {\n  most_recent = true\n\n  # Explanation: Canonical now publishes  official Ubuntu images on the Amazon cloud.\n  # Check supported versions here : https://uec-images.ubuntu.com/locator/\n  filter {\n    name   = "name"',
#   'metadata': {'filename': 'main.tf',
#    'filepath': '../data/terraform-examples/aws/aws_instance/ami_lookup/main.tf',
#    'filesize': 1744,
#    'project': 'ami_lookup',
#    'summary': 'Data Source for getting latest getting AMI Linux Imagehttps://docs.aws.amazon.com/AWSEC2/latest/UserGuide/finding-an-ami.html'}},
#  {'content': 'filter {\n    name   = "name"\n    values = ["ubuntu/images/hvm-ssd/ubuntu-hirsute-21.04-amd64-server-*"]\n  }\n\n  filter {\n    name   = "virtualization-type"\n    values = ["hvm"]\n  }\n\n  # Explanation: There are different Public providers (owners), like Canonical, AWS and others . Check here: https://docs.aws.amazon.com/AWSEC2/latest/UserGuide/finding-an-ami.html\n  # Some examples of owners:   099720109477 - Canonical and 679593333241 - AWS\n  owners = ["099720109477"]\n}',
#   'metadata': {'filename': 'main.tf',
#    'filepath': '../data/terraform-examples/aws/aws_instance/ami_lookup/main.tf',
#    'filesize': 1744,
#    'project': 'ami_lookup',
#    'summary': 'Data Source for getting latest getting AMI Linux Imagehttps://docs.aws.amazon.com/AWSEC2/latest/UserGuide/finding-an-ami.html'}},
#  {'content': 'owners = ["099720109477"]\n}\n\n# Documentation: https://registry.terraform.io/providers/hashicorp/aws/latest/docs/resources/instance',
#   'metadata': {'filename': 'main.tf',
#    'filepath': '../data/terraform-examples/aws/aws_instance/ami_lookup/main.tf',
#    'filesize': 1744,
#    'project': 'ami_lookup',
#    'summary': 'Data Source for getting latest getting AMI Linux Imagehttps://docs.aws.amazon.com/AWSEC2/latest/UserGuide/finding-an-ami.html'}},
#  {'content': 'resource "aws_instance" "changeme_ami_lookup_aws_instance" {\n  ami           = data.aws_ami.changeme_aws_ami.id\n  instance_type = "t3.micro"\n\n  tags = {\n    Name = "changeme_ami_lookup_aws_instance"\n  }\n}',
#   'metadata': {'filename': 'main.tf',
#    'filepath': '../data/terraform-examples/aws/aws_instance/ami_lookup/main.tf',
#    'filesize': 1744,
#    'project': 'ami_lookup',
#    'summary': 'Data Source for getting latest getting AMI Linux Imagehttps://docs.aws.amazon.com/AWSEC2/latest/UserGuide/finding-an-ami.html'}}]

# %% [markdown]
# ## 3. Creando embeddings
#
# Usando modelos como **OpenAIEmbeddings** o **HuggingFaceEmbeddings** se pueden crear embeddings de mayor relevancia. Para este ejemplo se usar[a LangChain.

# %%
import shutil
#from langchain.embeddings import OpenAIEmbeddings
from langchain.embeddings import HuggingFaceEmbeddings
#from langchain.vectorstores import FAISS
from langchain.vectorstores import Chroma
from langchain.docstore.document import Document


def create_chroma_vectorstore(docs, persist_directory="/tmp/chatlocal-chroma-db", replace=True):
    """Create the chrome vector store using the created docs"""
    print(persist_directory, replace, os.path.exists(persist_directory))
    if replace is True and os.path.exists(persist_directory):
        print(f'deleting {persist_directory}')
        shutil.rmtree(persist_directory)
    documents = [
        Document(page_content=doc["content"], metadata=doc["metadata"])
        for doc in docs
    ]
    embeddings = HuggingFaceEmbeddings()
    vectorstore = Chroma.from_documents(
        documents,
        embedding=embeddings,
        persist_directory=persist_directory
    )
    vectorstore.persist()  # Save to disk
    return vectorstore

vectorstore = create_chroma_vectorstore(chunk_snippets)
vectorstore
# Out:
# /tmp/chatlocal-chroma-db True False
# /tmp/ipykernel_17467/1297147795.py:19: LangChainDeprecationWarning: Default values for HuggingFaceEmbeddings.model_name were deprecated in LangChain 0.2.16 and will be removed in 0.4.0. Explicitly pass a model_name to the HuggingFaceEmbeddings constructor instead.
#   embeddings = HuggingFaceEmbeddings()
# Failed to send telemetry event ClientStartEvent: capture() takes 1 positional argument but 3 were given
# Failed to send telemetry event ClientCreateCollectionEvent: capture() takes 1 positional argument but 3 were given

# %%
# !ls ../data/terraform-examples/aws/aws_elb/classic_elb/main.tf
# !ls -lht /tmp/chatlocal-chroma-db
# Out:
# ../data/terraform-examples/aws/aws_elb/classic_elb/main.tf
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# total 142K
# -rw-r--r-- 1 rodrigo.garcia domain_users 2,2M sep 16 18:59 chroma.sqlite3
# drwxr-xr-x 2 rodrigo.garcia domain_users    6 sep 16 18:59 a540ea92-2fbb-4418-bd50-1c782311bad5

# %%
#### testing queries agains the Vector DB

retriever = vectorstore.as_retriever(search_kwargs={"k": 5})
docs = retriever.get_relevant_documents("How do I configure an S3 bucket with versioning?")
for doc in docs:
    print("📄 Content:", doc.page_content)
    print("📎 Metadata:", doc.metadata)
    print(">>>", doc)
    print("-" * 40)

print("How do I deploy an observable static site using NGINX?")
retriever = vectorstore.as_retriever(search_kwargs={"k": 5})
docs = retriever.get_relevant_documents("How do I deploy an observable static site using NGINX?")
for doc in docs:
    print("📄 Content:", doc.page_content)
    print("📎 Metadata:", doc.metadata)
    print("-" * 40)
# Out:
# Failed to send telemetry event CollectionQueryEvent: capture() takes 1 positional argument but 3 were given
# 📄 Content: resource "random_id" "changeme_bucket_name" {
#   byte_length = 16
# }
#
# # Documentation: https://registry.terraform.io/providers/hashicorp/aws/latest/docs/resources/s3_bucket
# resource "aws_s3_bucket" "changeme_aws_s3_bucket_simple" {
#   bucket = "te-${random_id.changeme_bucket_name.hex}"
# }
# 📎 Metadata: {'filename': 'main.tf', 'filepath': '../data/terraform-examples/aws/aws_s3_bucket/simple/main.tf', 'filesize': 1004, 'project': 'simple', 'summary': 'Create an S3 bucket'}
# >>> page_content='resource "random_id" "changeme_bucket_name" {
#   byte_length = 16
# }
#
# # Documentation: https://registry.terraform.io/providers/hashicorp/aws/latest/docs/resources/s3_bucket
# resource "aws_s3_bucket" "changeme_aws_s3_bucket_simple" {
#   bucket = "te-${random_id.changeme_bucket_name.hex}"
# }' metadata={'filename': 'main.tf', 'filepath': '../data/terraform-examples/aws/aws_s3_bucket/simple/main.tf', 'filesize': 1004, 'project': 'simple', 'summary': 'Create an S3 bucket'}
# ----------------------------------------
# 📄 Content: }
#   }
# }
#
# # Explanation: This resource is not necessary for the creation of an S3 bucket, but is here to ensure that
# # the S3 bucket name is unique.
# #
# # Documentation: https://registry.terraform.io/providers/hashicorp/random/latest/docs/resources/id
# 📎 Metadata: {'filename': 'main.tf', 'filepath': '../data/terraform-examples/aws/aws_s3_bucket/simple/main.tf', 'filesize': 1004, 'project': 'simple', 'summary': 'Create an S3 bucket'}
# >>> page_content='}
#   }
# }
#
# # Explanation: This resource is not necessary for the creation of an S3 bucket, but is here to ensure that
# # the S3 bucket name is unique.
# #
# # Documentation: https://registry.terraform.io/providers/hashicorp/random/latest/docs/resources/id' metadata={'filename': 'main.tf', 'filepath': '../data/terraform-examples/aws/aws_s3_bucket/simple/main.tf', 'filesize': 1004, 'project': 'simple', 'summary': 'Create an S3 bucket'}
# ----------------------------------------
# 📄 Content: # Summary: Create an S3 bucket
#
# # Documentation: https://www.terraform.io/docs/language/settings/index.html
# terraform {
#   required_version = ">= 1.0.0"
#   required_providers {
#     aws = {
#       source  = "hashicorp/aws"
#       version = "~> 3.38"
#     }
#   }
# }
#
# # Documentation: https://www.terraform.io/docs/language/providers/requirements.html
# provider "aws" {
#   region = "us-east-1"
#   default_tags {
#     tags = {
#       cs_terraform_examples = "aws_s3_bucket/simple"
#     }
#   }
# }
# 📎 Metadata: {'filename': 'main.tf', 'filepath': '../data/terraform-examples/aws/aws_s3_bucket/simple/main.tf', 'filesize': 1004, 'project': 'simple', 'summary': 'Create an S3 bucket'}
# >>> page_content='# Summary: Create an S3 bucket
#
# # Documentation: https://www.terraform.io/docs/language/settings/index.html
# terraform {
#   required_version = ">= 1.0.0"
#   required_providers {
#     aws = {
#       source  = "hashicorp/aws"
#       version = "~> 3.38"
#     }
#   }
# }
#
# # Documentation: https://www.terraform.io/docs/language/providers/requirements.html
# provider "aws" {
#   region = "us-east-1"
#   default_tags {
#     tags = {
#       cs_terraform_examples = "aws_s3_bucket/simple"
#     }
#   }
# }' metadata={'filename': 'main.tf', 'filepath': '../data/terraform-examples/aws/aws_s3_bucket/simple/main.tf', 'filesize': 1004, 'project': 'simple', 'summary': 'Create an S3 bucket'}
# ----------------------------------------
# 📄 Content: resource "aws_db_instance" "changeme_db_dev" {
#   instance_class      = "db.t2.micro"
#   identifier          = "changeme-db-from-backup"
#   snapshot_identifier = data.aws_db_snapshot.changeme_latest_prod_snapshot.id
#   skip_final_snapshot = true
#
#   lifecycle {
#     ignore_changes = [snapshot_identifier]
#   }
# }
# 📎 Metadata: {'filename': 'main.tf', 'filepath': '../data/terraform-examples/aws/aws_db_instance/restore_db_from_snapshot/main.tf', 'filesize': 2898, 'project': 'restore_db_from_snapshot', 'summary': 'Create a DB Instance PROD. Takes a snapshot (latest), and with the latest snapshot,creates a new DEV Instance.'}
# >>> page_content='resource "aws_db_instance" "changeme_db_dev" {
#   instance_class      = "db.t2.micro"
#   identifier          = "changeme-db-from-backup"
#   snapshot_identifier = data.aws_db_snapshot.changeme_latest_prod_snapshot.id
#   skip_final_snapshot = true
#
#   lifecycle {
#     ignore_changes = [snapshot_identifier]
#   }
# }' metadata={'filename': 'main.tf', 'filepath': '../data/terraform-examples/aws/aws_db_instance/restore_db_from_snapshot/main.tf', 'filesize': 2898, 'project': 'restore_db_from_snapshot', 'summary': 'Create a DB Instance PROD. Takes a snapshot (latest), and with the latest snapshot,creates a new DEV Instance.'}
# ----------------------------------------
# 📄 Content: # Summary: Create a Snapshot for a Given EBS Volume
#
# # Documentation: https://www.terraform.io/docs/language/settings/index.html
# terraform {
#   required_version = ">= 1.0.0"
#   required_providers {
#     aws = {
#       source  = "hashicorp/aws"
#       version = "~> 3.38"
#     }
#   }
# }
#
# # Documentation: https://www.terraform.io/docs/language/providers/requirements.html
# provider "aws" {
#   region = "us-east-1"
#   default_tags {
#     tags = {
#       cs_terraform_examples = "aws_ebs_volume/ebs_snapshot"
#     }
#   }
# }
# 📎 Metadata: {'filename': 'main.tf', 'filepath': '../data/terraform-examples/aws/aws_ebs_volume/ebs_snapshot/main.tf', 'filesize': 1782, 'project': 'ebs_snapshot', 'summary': 'Create a Snapshot for a Given EBS Volume'}
# >>> page_content='# Summary: Create a Snapshot for a Given EBS Volume
#
# # Documentation: https://www.terraform.io/docs/language/settings/index.html
# terraform {
#   required_version = ">= 1.0.0"
#   required_providers {
#     aws = {
#       source  = "hashicorp/aws"
#       version = "~> 3.38"
#     }
#   }
# }
#
# # Documentation: https://www.terraform.io/docs/language/providers/requirements.html
# provider "aws" {
#   region = "us-east-1"
#   default_tags {
#     tags = {
#       cs_terraform_examples = "aws_ebs_volume/ebs_snapshot"
#     }
#   }
# }' metadata={'filename': 'main.tf', 'filepath': '../data/terraform-examples/aws/aws_ebs_volume/ebs_snapshot/main.tf', 'filesize': 1782, 'project': 'ebs_snapshot', 'summary': 'Create a Snapshot for a Given EBS Volume'}
# ----------------------------------------
# How do I deploy an observable static site using NGINX?
# 📄 Content: }
# }
#
# # Documentation: https://registry.terraform.io/providers/hashicorp/aws/latest/docs/resources/elb
# # Explanation: Deploys the Classic Load Balancer, allows traffic in 8080 ports
# 📎 Metadata: {'filename': 'main.tf', 'filepath': '../data/terraform-examples/aws/aws_elb/classic_elb/main.tf', 'filesize': 3373, 'project': 'classic_elb', 'summary': 'Creates a simple Classic Elastic Load Balancer with two EC2 Instances'}
# ----------------------------------------
# 📄 Content: # Summary: Creates a simple Application Load Balancer and an ASG
#
# # Documentation: https://www.terraform.io/docs/language/settings/index.html
# terraform {
#   required_version = ">= 1.0.0"
#   required_providers {
#     aws = {
#       source  = "hashicorp/aws"
#       version = "~> 3.38"
#     }
#   }
# }
#
# # Documentation: https://www.terraform.io/docs/language/providers/requirements.html
# provider "aws" {
#   region = "us-east-1"
#   default_tags {
#     tags = {
#       cs_terraform_examples = "aws_elb/application_elb"
#     }
#   }
# }
# 📎 Metadata: {'filename': 'main.tf', 'filepath': '../data/terraform-examples/aws/aws_elb/application_elb/main.tf', 'filesize': 4079, 'project': 'application_elb', 'summary': 'Creates a simple Application Load Balancer and an ASG'}
# ----------------------------------------
# 📄 Content: resource "aws_instance" "changeme_first_aws_instance" {
#   ami                    = "ami-0c55b159cbfafe1f0"
#   instance_type          = "t2.micro"
#   availability_zone      = "us-east-2a"
#   vpc_security_group_ids = [aws_security_group.changeme_aws_security_group.id]
#   user_data              = <<-EOF
#               #!/bin/bash
#               echo "Hello, World from Host1" > index.html
#               nohup busybox httpd -f -p 8080 &
#               EOF
#   tags = {
#     Name = "changeme_first_aws_instance_tag"
#   }
# }
# 📎 Metadata: {'filename': 'main.tf', 'filepath': '../data/terraform-examples/aws/aws_elb/classic_elb/main.tf', 'filesize': 3373, 'project': 'classic_elb', 'summary': 'Creates a simple Classic Elastic Load Balancer with two EC2 Instances'}
# ----------------------------------------
# 📄 Content: map_public_ip_on_launch = true
# }
#
# # Documentation: https://registry.terraform.io/providers/hashicorp/aws/latest/docs/resources/route_table
# 📎 Metadata: {'filename': 'main.tf', 'filepath': '../data/terraform-examples/aws/aws_eks/fargate/spot_and_fargate/main.tf', 'filesize': 14603, 'project': 'spot_and_fargate', 'summary': 'See README.md'}
# ----------------------------------------
# 📄 Content: resource "aws_security_group" "changeme_aws_security_group" {
#   name        = "changeme-aws-security-group-classic-elb-name"
#   description = "Allow HTTP 8080 inbound traffic"
#   ingress {
#     from_port   = 8080
#     to_port     = 8080
#     protocol    = "tcp"
#     cidr_blocks = ["0.0.0.0/0"]
#   }
# }
#
# # Documentation: https://registry.terraform.io/providers/hashicorp/aws/latest/docs/resources/instance
# # Explanation: Deploys the first Server in us-east-2a
# 📎 Metadata: {'filename': 'main.tf', 'filepath': '../data/terraform-examples/aws/aws_elb/classic_elb/main.tf', 'filesize': 3373, 'project': 'classic_elb', 'summary': 'Creates a simple Classic Elastic Load Balancer with two EC2 Instances'}
# ----------------------------------------

# %% [markdown]
# ## 4. Combinando chunks extraídos antes de crear el prompt
#
# Cuando se consulta a la BD vectorial, retorna "pedazos" que pueden ser pedazos de archivos. Para no perder contexto semántico, intentaremos combinar pedazos que pertenezcan a un mismo archivo o quizá incluir el archivo completo, siempre y cuando no sea muy grande.

# %%
def group_by_filename(docs, max_total=12096):
    """Returns a dictionary with filenames with full contents of a file or only chunks
    depending on the file content size, wether this exeeds the `max_total' give.
    """
    grouped = {}
    size_used = 0
    doc_number = 0
    for doc in docs:
        print(f"used: {size_used}, doc number: {doc_number}")
        if (doc.metadata["filesize"] + size_used) > max_total:
            if (len(doc.page_content) + size_used) > max_total:
                # case where there are too much chunks
                print(f"Size used: {size_used}, Maybe too big files or too much chunks! This chunk size: {len(doc.page_content)}")
            else:
                key = f"{doc.metadata["filepath"]}_{doc_number}" if doc_number > 0 else doc.metadata["filepath"]
                print(f'Using chunk {key} ({len(doc.page_content)}) (entire: {doc.metadata["filesize"]})')
                grouped[key] = {
                    'metadata': {
                        'filename': doc.metadata['filename'],
                        'summary': doc.metadata['summary'],
                        'project': doc.metadata['project']
                    },
                    'content': doc.page_content
                }
                size_used += len(doc.page_content)
                doc_number += 1
        else:
            # if grouped.get(doc.metadata["filename"], None) is None:
            #     print('Already inserted, skipping')
            #     continue
            # use the whole file contents
            print(f'Using complete file {doc.metadata["filepath"]} ({doc.metadata["filesize"]})')
            with open(doc.metadata["filepath"], 'r') as f:
                grouped[doc.metadata["filepath"]] = {
                    'metadata': {
                        'filename': doc.metadata['filename'],
                        'summary': doc.metadata['summary'],
                        'project': doc.metadata['project']
                    },
                    'content': f.read()
                }
                #grouped[doc.metadata["filename"]] = f
                size_used += doc.metadata["filesize"]
    return grouped
    
combined_docs = group_by_filename(docs)
combined_docs

# %% [markdown]
# ## 5. Creando el prompt
#
# Con los pedazos extraídos de la BD vectorial se debe generar un prompt que le instruya al modelo que tome en cuenta prioritariamente los *chunks* extraídos de la BD vectorial y los use para dar la solución a la petición del usuario. Sino se encuentra solución entre ellos, generar una propia.

# %%
def generate_prompt_from_chunks(user_prompt, docs):
    """Generates a prompt for the given `user_prompt', using the extracted `docs'
    from vector DB.

    Returns: (str) with generated prompt
    """
    docs_formatted = ""
    for filepath, doc in docs.items():
        docs_formatted += f"""
        {filepath}:{doc['metadata']['filename']}
        {doc['metadata']['summary']}
        #-#-#
        {doc['content']}
        ----
        """
    
    prompt = f"""You will be given the following user request:
    {user_prompt}

    To give the solution here are some code snippets that are part of previous solutions
    already tested for the user not neccessarily for the specific user request, but are
    proven solutions. The snippets you will recieve are in format:
    (filepath):(filename)
    (summary_of_snippet)
    #-#-#
    (code_snippet)
    ------
    Here are the snippets:
    {docs_formatted}

    You will give more importance to these snippets to give the solution for the user request,
    when you use the snippets for the solution you will mention the reason you used one or more
    snippets with the format:
    (filepath):(filename)
    (reason)
    ----

    If you consider these snippets do not help to reach the requested solution, generate your
    own solutions mentioning that you did find enough reasons to use the snippets.
    """
    return prompt
print(generate_prompt_from_chunks('How do I deploy an observable static site using NGINX?', combined_docs))
# Out:
# You will be given the following user request:
#     How do I deploy an observable static site using NGINX?
#
#     To give the solution here are some code snippets that are part of previous solutions
#     already tested for the user not neccessarily for the specific user request, but are
#     proven solutions. The snippets you will recieve are in format:
#     (filepath):(filename)
#     (summary_of_snippet)
#     #-#-#
#     (code_snippet)
#     ------
#     Here are the snippets:
#
#         ../data/terraform-examples/aws/aws_elb/classic_elb/main.tf:main.tf
#         Creates a simple Classic Elastic Load Balancer with two EC2 Instances
#         #-#-#
#         # Summary: Creates a simple Classic Elastic Load Balancer with two EC2 Instances
# # Documentation: https://www.terraform.io/docs/language/settings/index.html
# terraform {
#   required_version = ">= 1.0.0"
#   required_providers {
#     aws = {
#       source  = "hashicorp/aws"
#       version = "~> 3.38"
#     }
#   }
# }
#
# # Documentation: https://www.terraform.io/docs/language/providers/requirements.html
# provider "aws" {
#   region = "us-east-2"
#   default_tags {
#     tags = {
#       cs_terraform_examples = "aws_elb/classic_elb"
#     }
#   }
# }
#
# # Documentation: https://registry.terraform.io/providers/hashicorp/aws/latest/docs/resources/security_group
# # See also: [aws/aws_security_group/ssh](https://github.com/ContainerSolutions/terraform-examples/tree/main/aws/aws_security_group/ssh)
# resource "aws_security_group" "changeme_aws_security_group" {
#   name        = "changeme-aws-security-group-classic-elb-name"
#   description = "Allow HTTP 8080 inbound traffic"
#   ingress {
#     from_port   = 8080
#     to_port     = 8080
#     protocol    = "tcp"
#     cidr_blocks = ["0.0.0.0/0"]
#   }
# }
#
# # Documentation: https://registry.terraform.io/providers/hashicorp/aws/latest/docs/resources/instance
# # Explanation: Deploys the first Server in us-east-2a
# resource "aws_instance" "changeme_first_aws_instance" {
#   ami                    = "ami-0c55b159cbfafe1f0"
#   instance_type          = "t2.micro"
#   availability_zone      = "us-east-2a"
#   vpc_security_group_ids = [aws_security_group.changeme_aws_security_group.id]
#   user_data              = <<-EOF
#               #!/bin/bash
#               echo "Hello, World from Host1" > index.html
#               nohup busybox httpd -f -p 8080 &
#               EOF
#   tags = {
#     Name = "changeme_first_aws_instance_tag"
#   }
# }
#
# # Documentation: https://registry.terraform.io/providers/hashicorp/aws/latest/docs/resources/instance
# # Explanation: Deploys the second Server in us-east-2b
# resource "aws_instance" "changeme_second_aws_instance" {
#   ami                    = "ami-0c55b159cbfafe1f0"
#   instance_type          = "t2.micro"
#   availability_zone      = "us-east-2b"
#   vpc_security_group_ids = [aws_security_group.changeme_aws_security_group.id]
#   user_data              = <<-EOF
#               #!/bin/bash
#               echo "Hello, World from Host2" > index.html
#               nohup busybox httpd -f -p 8080 &
#               EOF
#   tags = {
#     Name = "changeme_second_aws_instance_tag"
#   }
# }
#
# # Documentation: https://registry.terraform.io/providers/hashicorp/aws/latest/docs/resources/elb
# # Explanation: Deploys the Classic Load Balancer, allows traffic in 8080 ports
# resource "aws_elb" "changeme_simple_aws_elb" {
#   name               = "changeme-simple-aws-elb"
#   availability_zones = ["us-east-2a", "us-east-2b"]
#
#
#
#   listener {
#     instance_port     = 8080
#     instance_protocol = "http"
#     lb_port           = 8080
#     lb_protocol       = "http"
#   }
#
#   health_check {
#     healthy_threshold   = 10
#     unhealthy_threshold = 2
#     timeout             = 5
#     target              = "HTTP:8080/"
#     interval            = 10
#   }
#
#   instances                   = [aws_instance.changeme_first_aws_instance.id, aws_instance.changeme_second_aws_instance.id]
#   cross_zone_load_balancing   = true
#   idle_timeout                = 400
#   connection_draining         = true
#   connection_draining_timeout = 400
#
#   tags = {
#     Name = "changeme_simple_aws_elb_tag"
#   }
# }
#
#         ----
#
#         ../data/terraform-examples/aws/aws_elb/application_elb/main.tf:main.tf
#         Creates a simple Application Load Balancer and an ASG
#         #-#-#
#         # Summary: Creates a simple Application Load Balancer and an ASG
#
# # Documentation: https://www.terraform.io/docs/language/settings/index.html
# terraform {
#   required_version = ">= 1.0.0"
#   required_providers {
#     aws = {
#       source  = "hashicorp/aws"
#       version = "~> 3.38"
#     }
#   }
# }
#
# # Documentation: https://www.terraform.io/docs/language/providers/requirements.html
# provider "aws" {
#   region = "us-east-1"
#   default_tags {
#     tags = {
#       cs_terraform_examples = "aws_elb/application_elb"
#     }
#   }
# }
#
# # Documentation: https://registry.terraform.io/providers/hashicorp/aws/latest/docs/data-sources/vpc
# data "aws_vpc" "changeme_default_aws_vpc_alb" {
#   default = true
# }
#
# # Documentation: https://registry.terraform.io/providers/hashicorp/aws/latest/docs/data-sources/subnet_ids
# data "aws_subnet_ids" "changeme_aws_subnet_ids_alb" {
#   vpc_id = data.aws_vpc.changeme_default_aws_vpc_alb.id
# }
#
# # Documentation: https://registry.terraform.io/providers/hashicorp/aws/latest/docs/resources/security_group
# resource "aws_security_group" "changeme_alb_aws_security_group" {
#   name        = "changeme-simple-alb-security-group"
#   description = "Allow HTTP 80 inbound traffic"
#   ingress {
#     from_port   = 80
#     to_port     = 80
#     protocol    = "tcp"
#     cidr_blocks = ["0.0.0.0/0"]
#   }
#
#   egress {
#     from_port   = 0
#     to_port     = 0
#     protocol    = "-1"
#     cidr_blocks = ["0.0.0.0/0"]
#   }
# }
#
# # Documentation: https://registry.terraform.io/providers/hashicorp/aws/latest/docs/resources/lb_target_group
# resource "aws_lb_target_group" "changeme_simple_alb_target_group" {
#   name     = "changeme-simple-alb-target-group"
#   port     = 80
#   protocol = "HTTP"
#   vpc_id   = data.aws_vpc.changeme_default_aws_vpc_alb.id
#
#   health_check {
#     healthy_threshold   = 3
#     unhealthy_threshold = 2
#     interval            = 5
#     timeout             = 2
#     matcher             = "200"
#   }
# }
#
# # Documentation: https://registry.terraform.io/providers/hashicorp/aws/latest/docs/resources/lb
# resource "aws_lb" "changeme_simple_aws_alb" {
#   name               = "changeme-simple-alb"
#   internal           = false
#   load_balancer_type = "application"
#   subnets            = data.aws_subnet_ids.changeme_aws_subnet_ids_alb.ids
#   security_groups    = [aws_security_group.changeme_alb_aws_security_group.id]
# }
#
# # Documentation: https://registry.terraform.io/providers/hashicorp/aws/latest/docs/resources/lb_listener
# resource "aws_lb_listener" "changeme_simple_alb_listener" {
#   load_balancer_arn = aws_lb.changeme_simple_aws_alb.arn
#   port              = "80"
#   protocol          = "HTTP"
#
#   default_action {
#     type             = "forward"
#     target_group_arn = aws_lb_target_group.changeme_simple_alb_target_group.arn
#   }
# }
#
# # Documentation: https://registry.terraform.io/providers/hashicorp/aws/latest/docs/data-sources/ami
# data "aws_ami" "changeme_amazon_alb_ami" {
#   owners      = ["amazon"]
#   most_recent = true
#
#   filter {
#     name   = "name"
#     values = ["amzn2-ami-hvm*"]
#   }
# }
#
# # Documentation: https://registry.terraform.io/providers/hashicorp/aws/latest/docs/resources/launch_template
# resource "aws_launch_template" "changeme_simple_asg_launch_template_alb" {
#   name                   = "changeme-simple-asg-launch-template-alb"
#   image_id               = data.aws_ami.changeme_amazon_alb_ami.id #"ami-087c17d1fe0178315"
#   instance_type          = "t2.micro"
#   vpc_security_group_ids = [aws_security_group.changeme_alb_aws_security_group.id]
#   user_data              = filebase64("${path.module}/user_data.sh")
# }
#
# # Documentation: https://registry.terraform.io/providers/hashicorp/aws/latest/docs/resources/autoscaling_group
# resource "aws_autoscaling_group" "changeme_simple_autoscaling_group_alb" {
#   name               = "changeme-simple-autoscaling-group-alb"
#   availability_zones = ["us-east-1a", "us-east-1b"]
#   desired_capacity   = 2
#   max_size           = 2
#   min_size           = 2
#   target_group_arns  = [aws_lb_target_group.changeme_simple_alb_target_group.arn]
#
#   launch_template {
#     id = aws_launch_template.changeme_simple_asg_launch_template_alb.id
#   }
# }
#
#         ----
#
#         ../data/terraform-examples/aws/aws_eks/fargate/spot_and_fargate/main.tf:main.tf
#         See README.md
#         #-#-#
#         map_public_ip_on_launch = true
# }
#
# # Documentation: https://registry.terraform.io/providers/hashicorp/aws/latest/docs/resources/route_table
#         ----
#
#         ../data/terraform-examples/aws/aws_elb/classic_elb/main.tf_1:main.tf
#         Creates a simple Classic Elastic Load Balancer with two EC2 Instances
#         #-#-#
#         resource "aws_security_group" "changeme_aws_security_group" {
#   name        = "changeme-aws-security-group-classic-elb-name"
#   description = "Allow HTTP 8080 inbound traffic"
#   ingress {
#     from_port   = 8080
#     to_port     = 8080
#     protocol    = "tcp"
#     cidr_blocks = ["0.0.0.0/0"]
#   }
# }
#
# # Documentation: https://registry.terraform.io/providers/hashicorp/aws/latest/docs/resources/instance
# # Explanation: Deploys the first Server in us-east-2a
#         ----
#
#
#     You will give more importance to these snippets to give the solution for the user request,
#     when you use the snippets for the solution you will mention the reason you used one or more
#     snippets with the format:
#     (filepath):(filename)
#     (reason)
#     ----
#
#     If you consider these snippets do not help to reach the requested solution, generate your
#     own solutions mentioning that you did find enough reasons to use the snippets.

# %% [markdown]
# ## 6. Enviando al LLM
#
# El prompt construido se envía a un modelo de lenguage extenso generativo.

# %%
##### USING deepseek-reasoner MODEL FROM API ########
from getpass import getpass

deepseek_api_key = getpass("YOUR DEEPSEEK API:")
print('thanks!')

###### LLM Client #####
from openai import OpenAI
client_deepseek = OpenAI(
    api_key=deepseek_api_key,
    base_url="https://api.deepseek.com")
# Out:
# YOUR DEEPSEEK API: ········
# thanks!

# %%
def get_llm_api_response(client, prompt, model='deepseek-reasoner', temperature=0.17):
    print(f"Getting response from model {model}. Prompt lenght: {len(prompt)}")
    response = client.chat.completions.create(
        model=model,
        messages=[{
            "role": "system", 
            "content": "You are a devops engineer building infrastructure using AWS stack"
          },
          {
              "role": "user",
              "content": prompt
          }
        ],
        temperature=temperature,
    )
    return response

# %%
## Test complete user interaction

from IPython.display import Markdown
import json

REASONING_MODEL = 'deepseek-reasoner'

initial_prompt = input('Initial Prompt type here: ')

docs = retriever.get_relevant_documents(initial_prompt)
combined_docs = group_by_filename(docs)
prompt = generate_prompt_from_chunks(initial_prompt, combined_docs)
print()
response = get_llm_api_response(client_deepseek, prompt, REASONING_MODEL, 0.25)
print("======= RESPONSE ========")
#print(response.choices[0].message.content)

# Display with Markdown
Markdown(f"```terraform\n{response.choices[0].message.content}\n```")
# Out:
# Initial Prompt type here:  How do I deploy a static site (HTML+CSS+JS) with three instances of NGINX behind a load balancer.
# used: 0, doc number: 0
# Using complete file ../data/terraform-examples/aws/aws_elb/application_elb/main.tf (4079)
# used: 4079, doc number: 0
# Using complete file ../data/terraform-examples/aws/aws_elb/classic_elb/main.tf (3373)
# used: 7452, doc number: 0
# Using complete file ../data/terraform-examples/aws/aws_elb/network_elb/main.tf (3795)
# used: 11247, doc number: 0
# Using chunk ../data/terraform-examples/aws/aws_elb/classic_elb/main.tf (525) (entire: 3373)
# used: 11772, doc number: 1
# Size used: 11772, Maybe too big files or too much chunks! This chunk size: 419
#
# Getting response from model deepseek-reasoner. Prompt lenght: 9929
# ======= RESPONSE ========
# ```terraform
# Based on the user request and the provided snippets, I'll create a Terraform solution to deploy a static site with three NGINX instances behind an Application Load Balancer. The first snippet (aws_elb/application_elb/main.tf) provides the most relevant foundation for this use case.
#
# **Solution:**
#
# ```hxml
# # main.tf
# terraform {
#   required_version = ">= 1.0.0"
#   required_providers {
#     aws = {
#       source  = "hashicorp/aws"
#       version = "~> 3.38"
#     }
#   }
# }
#
# provider "aws" {
#   region = "us-east-1"
# }
#
# # Get default VPC and subnets
# data "aws_vpc" "default" {
#   default = true
# }
#
# data "aws_subnet_ids" "all" {
#   vpc_id = data.aws_vpc.default.id
# }
#
# # Security group for ALB
# resource "aws_security_group" "alb_sg" {
#   name        = "static-site-alb-sg"
#   description = "Allow HTTP traffic to ALB"
#
#   ingress {
#     from_port   = 80
#     to_port     = 80
#     protocol    = "tcp"
#     cidr_blocks = ["0.0.0.0/0"]
#   }
#
#   egress {
#     from_port   = 0
#     to_port     = 0
#     protocol    = "-1"
#     cidr_blocks = ["0.0.0.0/0"]
#   }
# }
#
# # Security group for EC2 instances
# resource "aws_security_group" "instance_sg" {
#   name        = "static-site-instance-sg"
#   description = "Allow HTTP from ALB and SSH for management"
#
#   ingress {
#     from_port       = 80
#     to_port         = 80
#     protocol        = "tcp"
#     security_groups = [aws_security_group.alb_sg.id]
#   }
#
#   ingress {
#     from_port   = 22
#     to_port     = 22
#     protocol    = "tcp"
#     cidr_blocks = ["0.0.0.0/0"] # Restrict this in production
#   }
#
#   egress {
#     from_port   = 0
#     to_port     = 0
#     protocol    = "-1"
#     cidr_blocks = ["0.0.0.0/0"]
#   }
# }
#
# # Target group for ALB
# resource "aws_lb_target_group" "static_site" {
#   name     = "static-site-tg"
#   port     = 80
#   protocol = "HTTP"
#   vpc_id   = data.aws_vpc.default.id
#
#   health_check {
#     path                = "/"
#     healthy_threshold   = 2
#     unhealthy_threshold = 2
#     timeout             = 3
#     interval            = 30
#     matcher             = "200-399"
#   }
# }
#
# # Application Load Balancer
# resource "aws_lb" "static_site" {
#   name               = "static-site-alb"
#   internal           = false
#   load_balancer_type = "application"
#   security_groups    = [aws_security_group.alb_sg.id]
#   subnets            = data.aws_subnet_ids.all.ids
# }
#
# # ALB listener
# resource "aws_lb_listener" "static_site" {
#   load_balancer_arn = aws_lb.static_site.arn
#   port              = 80
#   protocol          = "HTTP"
#
#   default_action {
#     type             = "forward"
#     target_group_arn = aws_lb_target_group.static_site.arn
#   }
# }
#
# # Get latest Amazon Linux 2 AMI
# data "aws_ami" "amazon_linux" {
#   most_recent = true
#   owners      = ["amazon"]
#
#   filter {
#     name   = "name"
#     values = ["amzn2-ami-hvm-*-x86_64-gp2"]
#   }
# }
#
# # User data script to install and configure NGINX
# data "template_file" "user_data" {
#   template = file("${path.module}/user_data.sh")
# }
#
# # Launch template for instances
# resource "aws_launch_template" "static_site" {
#   name                   = "static-site-launch-template"
#   image_id               = data.aws_ami.amazon_linux.id
#   instance_type          = "t2.micro"
#   vpc_security_group_ids = [aws_security_group.instance_sg.id]
#   user_data              = base64encode(data.template_file.user_data.rendered)
#
#   tag_specifications {
#     resource_type = "instance"
#     tags = {
#       Name = "static-site-instance"
#     }
#   }
# }
#
# # Auto Scaling Group with exactly 3 instances
# resource "aws_autoscaling_group" "static_site" {
#   name               = "static-site-asg"
#   availability_zones = ["us-east-1a", "us-east-1b", "us-east-1c"]
#   desired_capacity   = 3
#   max_size           = 3
#   min_size           = 3
#   target_group_arns  = [aws_lb_target_group.static_site.arn]
#
#   launch_template {
#     id = aws_launch_template.static_site.id
#   }
# }
#
# # Output the ALB DNS name
# output "alb_dns_name" {
#   value = aws_lb.static_site.dns_name
# }
# ```
#
# ```bash
# # user_data.sh
# #!/bin/bash
# yum update -y
# amazon-linux-extras install nginx1 -y
# systemctl start nginx
# systemctl enable nginx
#
# # Create static site directory and deploy your content
# mkdir -p /usr/share/nginx/html
# # Add your static files here or use S3 sync
# echo "<html><body><h1>Static Site Deployed Successfully</h1></body></html>" > /usr/share/nginx/html/index.html
# ```
#
# **Snippet Usage Justification:**
#
# `../data/terraform-examples/aws/aws_elb/application_elb/main.tf:main.tf`
# This snippet was used because it provides a complete, working example of an Application Load Balancer configuration with Auto Scaling Group, which is exactly what's needed for serving a static site behind a load balancer. The ALB is the appropriate choice for HTTP/HTTPS traffic routing to web servers.
#
# **Additional Notes:**
# 1. Replace the simple HTML in the user_data.sh with your actual static site content
# 2. For production use, consider:
#    - Adding HTTPS termination with ACM certificate
#    - Using S3 for static content storage
#    - Implementing proper logging and monitoring
#    - Restricting SSH access to specific IPs
# 3. The solution creates exactly 3 instances spread across 3 availability zones for high availability
# 4. Run `terraform apply` to deploy the infrastructure, then access your site via the ALB DNS name output
# ```
